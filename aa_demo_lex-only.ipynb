# %% [markdown]
# # Experiment I: Character Bigram Only

# %% [markdown]
# ## I. PREPROCESSING

# %%
import os
import cPickle
import random
import numpy as np
from string import punctuation as punc
from nltk import ngrams
from collections import defaultdict
from copy import deepcopy

# %%
data_dir = "/Users/jacobsw/Desktop/UNIV/SPRING_2017/CS388_NLP/PROJECT/DATA/19centurynovels/"

# %%
author2works = {'ab': ['agnes_grey.txt',
                      'the_tenant_of_wildfell_hall.txt'],
                'ja': ['emma.txt',
                      'mansfield_park.txt',
                      'sense_and_sensibility.txt'],
                'cb': ['jane_eyre.txt',
                      'the_professor.txt'],
                'jfc':['the_last_of_the_mohicans.txt',
                       'the_spy.txt',
                       'water_witch.txt'],
                'cd': ['bleak_house.txt',
                       'dombey_and_son.txt',
                       'great_expectations.txt'],
                'rwe':['the_conduct_of_life.txt',
                       'english_traits.txt'],
                'eb': ['wuthering_heights.txt'],
                'nh': ['the_house_of_the_seven_gables.txt'],
                'hm': ['moby_dick.txt',
                       'redburn.txt']}

author2name = {'ab': 'Anne Bronte', 'ja': 'Jane Austen', 'cb': 'Charlotte Bronte',
               'jfc': 'James Fenimore Cooper', 'cd': 'Charles Dickens',
               'rwe': 'Ralph Waldo Emerson', 'eb': 'Emily Bronte', 'nh': 'Nathaniel Hawthorne',
               'hm': 'Herman Melville'}

author2id = {'ab': 0, 'ja': 1, 'cb': 2, 'jfc': 3, 'cd': 4, 'rwe': 5, 'eb': 6, 'nh': 7, 'hm': 8}
num_cls = len(author2id)

seed = random.random()

# %% [markdown]
# ### A. CHUNKING

# %%
charchunk_size = 1000 # for chunk_size = 200
# charchunk_size = 5000 # for chunk_size = 1000
# charchunk_size = 10000 # for chunk_size = 2000

def doc2words(path):
    words = []
    for line in open(path):
        line = line.strip().decode('ascii','ignore').encode("utf-8")
        if len(line)<1: continue
        for item in line.split():
            if item[-1] in punc:
                words.append(item[:-1])
                words.append(item[-1])
                continue
            words.append(item)
    return words

def chunkize(words, size=100):
    m = max(1, size)
    n = len(words)
    chunks = [words[i:i+m] for i in xrange(0, n, m)]
    return chunks if len(chunks[-1])==size else chunks[:-1]

def to_chars(chunk):
    chars = ''
    for i in range(len(chunk)-1):
        chars += chunk[i]+' ' if chunk[i+1] not in punc else chunk[i]
    return chars

def pad(chars):
    char_len = len(chars)
    if char_len<charchunk_size:
        return chars + ' '*(charchunk_size-char_len)
    return chars[:charchunk_size]    

def to_ngrams(chars, n=2):
    return list(ngrams(chars, n))

# %% [markdown]
# ### B. FEATURIZE TO RAW STRINGS

# %%
# FEATURIZE TO RAW STRINGS

def author_featurize(author, size):
    assert author in author2works
    bichars_data = []
    for work in author2works[author]:
        words = doc2words(data_dir + work)
        chunks = chunkize(words, size)
        for chunk in chunks:            
            bichars_data.append((to_ngrams(pad(to_chars(chunk)), 2), author))
    return np.array(bichars_data)

def resample(data, data_size, sample_size):
    if sample_size==0: return data
    sample_indices = np.random.choice(range(data_size),size=sample_size)
    return np.concatenate([data,data[sample_indices]],axis=0)

def featurize(size):
    data = []
    for author in author2works.iterkeys():
        print "... featurizing:", author 
        data.append(author_featurize(author, size))
    max_size = max([len(author_data) for author_data in data])
    data = [resample(author_data,len(author_data),max_size-len(author_data)) for author_data in data]
    data = np.concatenate(data, axis=0)
    author2data = defaultdict(list)
    for entry in data:
        author2data[entry[1]].append(entry)
    for author,data in author2data.iteritems():
        author2data[author] = np.array(data)
    return author2data
        

author2data = featurize(size=200)
# Out:
# ... featurizing: nh
# ... featurizing: ab
# ... featurizing: rwe
# ... featurizing: hm
# ... featurizing: jfc
# ... featurizing: cb
# ... featurizing: eb
# ... featurizing: ja
# ... featurizing: cd

# %%
# Checking
for author,data in author2data.iteritems():
    print author, data.shape, data[0][1]
# Out:
# nh (5237, 2) nh
# ab (5237, 2) ab
# rwe (5237, 2) rwe
# jfc (5237, 2) jfc
# cb (5237, 2) cb
# eb (5237, 2) eb
# hm (5237, 2) hm
# cd (5237, 2) cd
# ja (5237, 2) ja

# %% [markdown]
# ### C. FEATURIZE TO INDICES

# %%
##### AUTHOR-BALANCED #####

vocab_size = 0

# Visualization
index2bichar = {}

def partition(data, k, shuffle=True):
    if shuffle:
        random.shuffle(data)
    k = max(1,k)
    num_rows = len(data)
    part_size = num_rows//k
    if num_rows%k==0:
        return [data[i:i+part_size] for i in xrange(0,num_rows,part_size)]
    return [data[i:i+part_size] if idx<k-1 else data[i:] 
            for idx,i in enumerate(xrange(0,num_rows,part_size))][:-1]

def cv_split(author2data, test_fold=0, k=5):
    train, test = [], []
    for data in author2data.itervalues():
        parts = partition(data, k)
        train.append(np.concatenate([fold for i,fold in enumerate(parts) if i!=test_fold]))
        test.append(parts[test_fold])
    return np.concatenate(train), np.concatenate(test)
        
def vectorize(author):
    vec = np.zeros(num_cls)
    vec[author2id[author]] = 1
    return vec

def get_id(item, dic, unk=False):
    if unk: return len(dic)
    if item not in dic:
        new_index = len(dic)
        dic[item] = new_index
        index2bichar[new_index] = item
    return dic[item]

def to_onehot(data, test_fold, num_folds):
    
    train, test = cv_split(data, test_fold, num_folds)
    
    print 'Train size:', len(train)
    print 'Test size:', len(test)
    
    X_train, X_test, Y_train, Y_test = [], [], [], []
    
    bichar_dic = {}
    for bichars,a in train:
        bichar_ids = [get_id(bichar,bichar_dic) for bichar in bichars]
        X_train.append(bichar_ids)
        Y_train.append(vectorize(a))
    global vocab_size
    vocab_size = len(bichar_dic) + 1
    print "vocab size", vocab_size
    
    for bichars,a in test:
        bichar_ids = [get_id(bichar,bichar_dic) if bichar in bichar_dic else get_id(bichar,bichar_dic,unk=True) 
                      for bichar in bichars]
        X_test.append(bichar_ids)
        Y_test.append(vectorize(a))
    global index2bichar
    index2bichar[len(bichar_dic)] = '<unk>'
        
    return np.array(X_train), np.array(X_test), np.array(Y_train), np.array(Y_test)

# %%
# %%time
X_train, X_test, Y_train, Y_test = to_onehot(author2data, test_fold=4, num_folds=5)
# Out:
# Train size: 37692
# Test size: 9441
# vocab size 2795
# CPU times: user 20.4 s, sys: 455 ms, total: 20.8 s
# Wall time: 20.9 s

# %%
class DataIterator:
    
    def __init__(self, X, Y):
        self.X = deepcopy(X)
        self.Y = deepcopy(Y)
        self.size = len(X)
        self.indices = np.arange(self.size)
        self.epoch = 0
        self.cursor = 0
        self.shuffle()
    
    def shuffle(self):
        random.shuffle(self.indices)
        self.X = self.X[self.indices]
        self.Y = self.Y[self.indices]
        self.cursor = 0
    
    def next_batch(self, n):
        if self.cursor+n > self.size:
            self.epoch += 1
            self.shuffle()
        X_batch, Y_batch = self.X[self.cursor:self.cursor+n], self.Y[self.cursor:self.cursor+n]
        self.cursor += n
        return X_batch, Y_batch

# %% [markdown]
# ## II. CONV NETS

# %%
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
def reset_graph():
    # Clean existing graph before start.
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()

# %%
####################################################################################################
################################ SHAPE/CHANNEL ARGUMENTS ###########################################
####################################################################################################
# a = tf.placeholder(tf.float32, shape=[1,5,10,1]) # shape=[batch,height/#row,width/#col,#channels]
# f = tf.constant(1.0, shape=[5,3,1,4]) # shape=[height/#row,width/#col,#channels,#ft_maps]
# a_conv = tf.nn.conv2d(a, f, strides=[1,1,1,1], padding='VALID') # strides: step size along dimensions.
# a_maxpool = tf.nn.max_pool(a_conv, ksize=[1,1,8,1], strides=[1,1,8,1], padding='VALID')

# # SHAPES 
# #   Tensor("Placeholder_3:0", shape=(1, 5, 10, 1), dtype=float32)
# #   Tensor("Const_2:0", shape=(5, 3, 1, 10), dtype=float32)
# #   Tensor("Conv2D_2:0", shape=(1, 1, 8, 10), dtype=float32)
# #   Tensor("MaxPool_1:0", shape=(1, 1, 1, 4), dtype=float32)
# # CHANNELS
# #   Channels are summed up: 
# #   http://stackoverflow.com/questions/27728531/convolutional-neural-networks-multiple-channels
####################################################################################################

# %%
reset_graph()

evaluate_train = False

x_size = charchunk_size - 1 # bigrams size = unigrams size - 1
emb_size = 50

reg = True
l2_reg_lambda = 0.01

X = tf.placeholder(tf.float32, shape=[None, x_size], name='bichars')
y = tf.placeholder(tf.float32, shape=[None, num_cls], name='labels')

# def get_embedding(X_):
#     emb = tf.Variable(tf.random_uniform([vocab_size, emb_size], -1.0, 1.0), name='embeddings')
#     return tf.nn.embedding_lookup(emb, tf.cast(X_, tf.int32))
# X_emb = get_embedding(X)

emb = tf.Variable(tf.random_uniform([vocab_size, emb_size], -1.0, 1.0), name='embeddings')
X_emb = tf.nn.embedding_lookup(emb, tf.cast(X, tf.int32))

X_input = tf.expand_dims(X_emb, -1)

flt1_height = 3 # 3 item window
flt2_height = 4 # 4 item window
flt3_height = 5 # 5 item window
flt_width  = emb_size
num_chnls  = 1
num_ftmaps = 30

def initialize_variable(shape, vtype, name):
    return tf.get_variable(name, shape=shape, initializer=tf.contrib.layers.xavier_initializer()) if vtype=='W' else \
           tf.Variable(tf.constant(0.1, shape=shape), name)
def init_wgts():
    W1 = initialize_variable([flt1_height,flt_width,num_chnls,num_ftmaps], vtype='W', name='W1')
    W2 = initialize_variable([flt2_height,flt_width,num_chnls,num_ftmaps], vtype='W', name='W2')
    W3 = initialize_variable([flt3_height,flt_width,num_chnls,num_ftmaps], vtype='W', name='W3')
    return W1, W2, W3
def init_bias():
    b1 = initialize_variable([num_ftmaps], vtype='b', name='b1') 
    b2 = initialize_variable([num_ftmaps], vtype='b', name='b2') 
    b3 = initialize_variable([num_ftmaps], vtype='b', name='b3') 
    return b1, b2, b3 

W1_conv, W2_conv, W3_conv = init_wgts()
b1_conv, b2_conv, b3_conv = init_bias()

keep_prob = tf.placeholder(tf.float32)
def conv2d(X_input_, W_):
    return tf.nn.conv2d(X_input_, W_, 
                        strides=[1,1,1,1], 
                        padding='VALID')
def max_pool(h, flt_height): 
    return tf.nn.max_pool(h, 
                          ksize=[1,x_size-flt_height+1,1,1], 
                          strides=[1,1,1,1], 
                          padding='VALID') 
        # NB: [batch,height/#row,width/#col,#channels]
def pool_vec(X_input_, W_, b_, flt_height):
    h_conv = tf.nn.relu(tf.nn.bias_add(conv2d(X_input_, W_), b_))
    h_pool = max_pool(h_conv, flt_height)
    return h_pool

h1_vec = pool_vec(X_input, W1_conv, b1_conv, flt1_height)
h2_vec = pool_vec(X_input, W2_conv, b2_conv, flt2_height)
h3_vec = pool_vec(X_input, W3_conv, b3_conv, flt3_height)

X_vec = tf.nn.dropout(tf.reshape(tf.concat([h1_vec,h2_vec,h3_vec], 3), [-1, num_ftmaps*3]), keep_prob)

W = tf.get_variable("W",shape=[num_ftmaps*3, num_cls],initializer=tf.contrib.layers.xavier_initializer())
b = tf.Variable(tf.constant(0.1, shape=[num_cls],name="b"))
l2_loss = tf.constant(0.0)
l2_loss += tf.nn.l2_loss(W)
l2_loss += tf.nn.l2_loss(b)

logits  = tf.nn.xw_plus_b(X_vec, W, b, name="logits")
softmax = tf.nn.softmax(logits)
y_pred  = tf.argmax(softmax, 1, name="predictions")
# y_pred = tf.argmax(logits, 1, name="predictions")
y_true = tf.argmax(y, 1)

if reg:
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y)) + l2_reg_lambda * l2_loss
else:
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))

correct = tf.equal(y_pred, y_true)
accuracy = tf.reduce_mean(tf.cast(correct, 'float'), name="accuracy")

train = tf.train.AdamOptimizer(1e-4).minimize(loss)

# Visualization (Li et al., 2016; Shrestha et al., 2017)
salience_grads = tf.gradients(loss, X_emb)[0]

batch_size = 32
num_epochs = 20

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    gen = DataIterator(X_train, Y_train)
    num_iters = 0
    train_losses, train_accs = [], []
    while gen.epoch<num_epochs:
        num_iters += 1
        X_batch, Y_batch = gen.next_batch(batch_size)
        _, train_loss, train_acc = sess.run([train, loss, accuracy], 
                                             feed_dict={X:X_batch, 
                                                        y:Y_batch, 
                                                        keep_prob:0.75})
        if num_iters%10==0:
            train_losses.append(train_loss)
            train_accs.append(train_acc)
            print "Stats:", "epoch =", gen.epoch, "| iters =", num_iters, "| loss:", train_loss, "| acc:", train_acc
            
    if evaluate_train:
        train_loss, train_acc, train_true, train_pred = sess.run([loss, accuracy, y_true, y_pred], 
                                                                  feed_dict={X:X_train, 
                                                                             y:Y_train, 
                                                                             keep_prob:1.0})
        prec = precision_score(train_true, train_pred)
        rec = recall_score(train_true, train_pred)
        f1 = f1_score(train_true, train_pred)    
        print
        print "Train Stats:"
        print "    loss =", train_loss, "| acc =", train_acc
        print "    prec =", prec, "| rec =", rec, "| f1 =", f1    
    grads, test_loss, test_acc, test_true, test_pred = sess.run([salience_grads, loss, accuracy, y_true, y_pred], 
                                                                 feed_dict={X:X_test, 
                                                                            y:Y_test, 
                                                                            keep_prob:1.0})
    
    prec = precision_score(test_true, test_pred, average='micro')
    rec = recall_score(test_true, test_pred, average='micro')
    f1 = f1_score(test_true, test_pred, average='micro')    
    print
    print "Test Stats:"
    print "    loss =", test_loss, "| acc:", test_acc
    print "    prec =", prec, "| rec =", rec, "| f1 =", f1
# Out:
# Stats: epoch = 0 | iters = 10 | loss: 2.59837 | acc: 0.0625
# Stats: epoch = 0 | iters = 20 | loss: 2.53066 | acc: 0.03125
# Stats: epoch = 0 | iters = 30 | loss: 2.55226 | acc: 0.03125
# Stats: epoch = 0 | iters = 40 | loss: 2.58756 | acc: 0.09375
# Stats: epoch = 0 | iters = 50 | loss: 2.20852 | acc: 0.21875
# Stats: epoch = 0 | iters = 60 | loss: 2.50438 | acc: 0.03125
# Stats: epoch = 0 | iters = 70 | loss: 2.34334 | acc: 0.15625
# Stats: epoch = 0 | iters = 80 | loss: 2.36244 | acc: 0.09375
# Stats: epoch = 0 | iters = 90 | loss: 2.32514 | acc: 0.21875
# Stats: epoch = 0 | iters = 100 | loss: 2.31181 | acc: 0.125
# Stats: epoch = 0 | iters = 110 | loss: 2.35102 | acc: 0.1875
# Stats: epoch = 0 | iters = 120 | loss: 2.33546 | acc: 0.0625
# Stats: epoch = 0 | iters = 130 | loss: 2.26603 | acc: 0.15625
# Stats: epoch = 0 | iters = 140 | loss: 2.20307 | acc: 0.1875
# Stats: epoch = 0 | iters = 150 | loss: 2.36271 | acc: 0.15625
# Stats: epoch = 0 | iters = 160 | loss: 2.23546 | acc: 0.21875
# Stats: epoch = 0 | iters = 170 | loss: 2.43306 | acc: 0.15625
# Stats: epoch = 0 | iters = 180 | loss: 2.15001 | acc: 0.1875
# Stats: epoch = 0 | iters = 190 | loss: 2.27358 | acc: 0.125
# Stats: epoch = 0 | iters = 200 | loss: 2.32742 | acc: 0.125
# Stats: epoch = 0 | iters = 210 | loss: 2.21576 | acc: 0.21875
# Stats: epoch = 0 | iters = 220 | loss: 2.18361 | acc: 0.1875
# Stats: epoch = 0 | iters = 230 | loss: 2.2566 | acc: 0.15625
# Stats: epoch = 0 | iters = 240 | loss: 2.22874 | acc: 0.125
# Stats: epoch = 0 | iters = 250 | loss: 2.16305 | acc: 0.21875
# Stats: epoch = 0 | iters = 260 | loss: 2.15279 | acc: 0.25
# Stats: epoch = 0 | iters = 270 | loss: 2.30458 | acc: 0.21875
# Stats: epoch = 0 | iters = 280 | loss: 2.21383 | acc: 0.15625
# Stats: epoch = 0 | iters = 290 | loss: 2.29015 | acc: 0.15625
# Stats: epoch = 0 | iters = 300 | loss: 2.09395 | acc: 0.3125
# Stats: epoch = 0 | iters = 310 | loss: 2.12713 | acc: 0.21875
# Stats: epoch = 0 | iters = 320 | loss: 2.32963 | acc: 0.21875
# Stats: epoch = 0 | iters = 330 | loss: 2.17828 | acc: 0.25
# Stats: epoch = 0 | iters = 340 | loss: 2.32642 | acc: 0.125
# Stats: epoch = 0 | iters = 350 | loss: 2.38239 | acc: 0.125
# Stats: epoch = 0 | iters = 360 | loss: 2.2807 | acc: 0.1875
# Stats: epoch = 0 | iters = 370 | loss: 1.98464 | acc: 0.34375
# Stats: epoch = 0 | iters = 380 | loss: 2.19705 | acc: 0.21875
# Stats: epoch = 0 | iters = 390 | loss: 2.17533 | acc: 0.21875
# Stats: epoch = 0 | iters = 400 | loss: 2.06978 | acc: 0.28125
# Stats: epoch = 0 | iters = 410 | loss: 2.20069 | acc: 0.28125
# Stats: epoch = 0 | iters = 420 | loss: 2.18195 | acc: 0.1875
# Stats: epoch = 0 | iters = 430 | loss: 2.16797 | acc: 0.21875
# Stats: epoch = 0 | iters = 440 | loss: 1.9743 | acc: 0.3125
# Stats: epoch = 0 | iters = 450 | loss: 2.123 | acc: 0.34375
# Stats: epoch = 0 | iters = 460 | loss: 2.13645 | acc: 0.21875
# Stats: epoch = 0 | iters = 470 | loss: 2.24323 | acc: 0.1875
# Stats: epoch = 0 | iters = 480 | loss: 2.10248 | acc: 0.21875
# Stats: epoch = 0 | iters = 490 | loss: 2.03839 | acc: 0.3125
# Stats: epoch = 0 | iters = 500 | loss: 2.00677 | acc: 0.34375
# Stats: epoch = 0 | iters = 510 | loss: 2.04496 | acc: 0.3125
# Stats: epoch = 0 | iters = 520 | loss: 1.9695 | acc: 0.21875
# Stats: epoch = 0 | iters = 530 | loss: 2.03255 | acc: 0.40625
# Stats: epoch = 0 | iters = 540 | loss: 2.1311 | acc: 0.21875
# Stats: epoch = 0 | iters = 550 | loss: 2.07768 | acc: 0.25
# Stats: epoch = 0 | iters = 560 | loss: 2.09828 | acc: 0.25
# Stats: epoch = 0 | iters = 570 | loss: 1.97552 | acc: 0.28125
# Stats: epoch = 0 | iters = 580 | loss: 2.23173 | acc: 0.21875
# Stats: epoch = 0 | iters = 590 | loss: 1.98043 | acc: 0.28125
# Stats: epoch = 0 | iters = 600 | loss: 1.90275 | acc: 0.4375
# Stats: epoch = 0 | iters = 610 | loss: 2.06366 | acc: 0.28125
# Stats: epoch = 0 | iters = 620 | loss: 2.01907 | acc: 0.1875
# Stats: epoch = 0 | iters = 630 | loss: 1.90018 | acc: 0.40625
# Stats: epoch = 0 | iters = 640 | loss: 2.02251 | acc: 0.28125
# Stats: epoch = 0 | iters = 650 | loss: 2.06246 | acc: 0.15625
# Stats: epoch = 0 | iters = 660 | loss: 2.16269 | acc: 0.1875
# Stats: epoch = 0 | iters = 670 | loss: 1.96982 | acc: 0.28125
# Stats: epoch = 0 | iters = 680 | loss: 1.87776 | acc: 0.40625
# Stats: epoch = 0 | iters = 690 | loss: 2.07541 | acc: 0.25
# Stats: epoch = 0 | iters = 700 | loss: 1.95702 | acc: 0.21875
# Stats: epoch = 0 | iters = 710 | loss: 1.92153 | acc: 0.28125
# Stats: epoch = 0 | iters = 720 | loss: 1.97262 | acc: 0.28125
# Stats: epoch = 0 | iters = 730 | loss: 2.07087 | acc: 0.21875
# Stats: epoch = 0 | iters = 740 | loss: 1.90974 | acc: 0.46875
# Stats: epoch = 0 | iters = 750 | loss: 1.89058 | acc: 0.375
# Stats: epoch = 0 | iters = 760 | loss: 1.78181 | acc: 0.40625
# Stats: epoch = 0 | iters = 770 | loss: 2.00419 | acc: 0.28125
# Stats: epoch = 0 | iters = 780 | loss: 2.05051 | acc: 0.28125
# Stats: epoch = 0 | iters = 790 | loss: 1.90221 | acc: 0.28125
# Stats: epoch = 0 | iters = 800 | loss: 1.74008 | acc: 0.46875
# Stats: epoch = 0 | iters = 810 | loss: 2.01892 | acc: 0.3125
# Stats: epoch = 0 | iters = 820 | loss: 1.96947 | acc: 0.1875
# Stats: epoch = 0 | iters = 830 | loss: 1.77528 | acc: 0.4375
# Stats: epoch = 0 | iters = 840 | loss: 1.73115 | acc: 0.4375
# Stats: epoch = 0 | iters = 850 | loss: 1.99122 | acc: 0.40625
# Stats: epoch = 0 | iters = 860 | loss: 1.7963 | acc: 0.46875
# Stats: epoch = 0 | iters = 870 | loss: 1.67255 | acc: 0.625
# Stats: epoch = 0 | iters = 880 | loss: 1.64634 | acc: 0.5625
# Stats: epoch = 0 | iters = 890 | loss: 1.6381 | acc: 0.5
# Stats: epoch = 0 | iters = 900 | loss: 1.66795 | acc: 0.46875
# Stats: epoch = 0 | iters = 910 | loss: 1.76474 | acc: 0.40625
# Stats: epoch = 0 | iters = 920 | loss: 1.7303 | acc: 0.46875
# Stats: epoch = 0 | iters = 930 | loss: 1.78671 | acc: 0.4375
# Stats: epoch = 0 | iters = 940 | loss: 1.85135 | acc: 0.375
# Stats: epoch = 0 | iters = 950 | loss: 1.69852 | acc: 0.4375
# Stats: epoch = 0 | iters = 960 | loss: 1.80987 | acc: 0.375
# Stats: epoch = 0 | iters = 970 | loss: 1.72341 | acc: 0.53125
# Stats: epoch = 0 | iters = 980 | loss: 1.85993 | acc: 0.375
# Stats: epoch = 0 | iters = 990 | loss: 1.72337 | acc: 0.5
# Stats: epoch = 0 | iters = 1000 | loss: 1.6976 | acc: 0.4375
# Stats: epoch = 0 | iters = 1010 | loss: 1.6651 | acc: 0.5
# Stats: epoch = 0 | iters = 1020 | loss: 1.69385 | acc: 0.5625
# Stats: epoch = 0 | iters = 1030 | loss: 1.7449 | acc: 0.40625
# Stats: epoch = 0 | iters = 1040 | loss: 1.69207 | acc: 0.5
# Stats: epoch = 0 | iters = 1050 | loss: 1.68671 | acc: 0.46875
# Stats: epoch = 0 | iters = 1060 | loss: 1.77035 | acc: 0.40625
# Stats: epoch = 0 | iters = 1070 | loss: 1.55631 | acc: 0.4375
# Stats: epoch = 0 | iters = 1080 | loss: 1.83158 | acc: 0.5
# Stats: epoch = 0 | iters = 1090 | loss: 1.6515 | acc: 0.4375
# Stats: epoch = 0 | iters = 1100 | loss: 1.70602 | acc: 0.53125
# Stats: epoch = 0 | iters = 1110 | loss: 1.80871 | acc: 0.40625
# Stats: epoch = 0 | iters = 1120 | loss: 1.49395 | acc: 0.59375
# Stats: epoch = 0 | iters = 1130 | loss: 1.96018 | acc: 0.28125
# Stats: epoch = 0 | iters = 1140 | loss: 1.63384 | acc: 0.46875
# Stats: epoch = 0 | iters = 1150 | loss: 1.80986 | acc: 0.4375
# Stats: epoch = 0 | iters = 1160 | loss: 1.84562 | acc: 0.4375
# Stats: epoch = 0 | iters = 1170 | loss: 1.54138 | acc: 0.53125
# Stats: epoch = 1 | iters = 1180 | loss: 1.75435 | acc: 0.4375
# Stats: epoch = 1 | iters = 1190 | loss: 1.76544 | acc: 0.3125
# Stats: epoch = 1 | iters = 1200 | loss: 1.48199 | acc: 0.5625
# Stats: epoch = 1 | iters = 1210 | loss: 1.87196 | acc: 0.3125
# Stats: epoch = 1 | iters = 1220 | loss: 1.68687 | acc: 0.5
# Stats: epoch = 1 | iters = 1230 | loss: 1.73893 | acc: 0.375
# Stats: epoch = 1 | iters = 1240 | loss: 1.59896 | acc: 0.53125
# Stats: epoch = 1 | iters = 1250 | loss: 1.67006 | acc: 0.4375
# Stats: epoch = 1 | iters = 1260 | loss: 1.65517 | acc: 0.4375
# Stats: epoch = 1 | iters = 1270 | loss: 1.93888 | acc: 0.34375
# Stats: epoch = 1 | iters = 1280 | loss: 1.48095 | acc: 0.625
# Stats: epoch = 1 | iters = 1290 | loss: 1.47467 | acc: 0.59375
# Stats: epoch = 1 | iters = 1300 | loss: 1.65851 | acc: 0.5
# Stats: epoch = 1 | iters = 1310 | loss: 1.72164 | acc: 0.28125
# Stats: epoch = 1 | iters = 1320 | loss: 1.48662 | acc: 0.59375
# Stats: epoch = 1 | iters = 1330 | loss: 1.42747 | acc: 0.53125
# Stats: epoch = 1 | iters = 1340 | loss: 1.59477 | acc: 0.5
# Stats: epoch = 1 | iters = 1350 | loss: 1.83179 | acc: 0.46875
# Stats: epoch = 1 | iters = 1360 | loss: 1.47651 | acc: 0.5625
# Stats: epoch = 1 | iters = 1370 | loss: 1.4428 | acc: 0.53125
# Stats: epoch = 1 | iters = 1380 | loss: 1.69674 | acc: 0.34375
# Stats: epoch = 1 | iters = 1390 | loss: 1.61276 | acc: 0.40625
# Stats: epoch = 1 | iters = 1400 | loss: 1.50445 | acc: 0.4375
# Stats: epoch = 1 | iters = 1410 | loss: 1.45525 | acc: 0.5625
# Stats: epoch = 1 | iters = 1420 | loss: 1.57491 | acc: 0.53125
# Stats: epoch = 1 | iters = 1430 | loss: 1.45196 | acc: 0.5625
# Stats: epoch = 1 | iters = 1440 | loss: 1.77562 | acc: 0.5
# Stats: epoch = 1 | iters = 1450 | loss: 1.54319 | acc: 0.46875
# Stats: epoch = 1 | iters = 1460 | loss: 1.44968 | acc: 0.65625
# Stats: epoch = 1 | iters = 1470 | loss: 1.43597 | acc: 0.5625
# Stats: epoch = 1 | iters = 1480 | loss: 1.74722 | acc: 0.34375
# Stats: epoch = 1 | iters = 1490 | loss: 1.64335 | acc: 0.40625
# Stats: epoch = 1 | iters = 1500 | loss: 1.39578 | acc: 0.625
# Stats: epoch = 1 | iters = 1510 | loss: 1.55963 | acc: 0.5625
# Stats: epoch = 1 | iters = 1520 | loss: 1.42177 | acc: 0.5
# Stats: epoch = 1 | iters = 1530 | loss: 1.39742 | acc: 0.65625
# Stats: epoch = 1 | iters = 1540 | loss: 1.36232 | acc: 0.625
# Stats: epoch = 1 | iters = 1550 | loss: 1.62505 | acc: 0.46875
# Stats: epoch = 1 | iters = 1560 | loss: 1.43871 | acc: 0.46875
# Stats: epoch = 1 | iters = 1570 | loss: 1.35416 | acc: 0.59375
# Stats: epoch = 1 | iters = 1580 | loss: 1.61024 | acc: 0.5
# Stats: epoch = 1 | iters = 1590 | loss: 1.61501 | acc: 0.5
# Stats: epoch = 1 | iters = 1600 | loss: 1.50826 | acc: 0.5
# Stats: epoch = 1 | iters = 1610 | loss: 1.5271 | acc: 0.53125
# Stats: epoch = 1 | iters = 1620 | loss: 1.56277 | acc: 0.46875
# Stats: epoch = 1 | iters = 1630 | loss: 1.58265 | acc: 0.46875
# Stats: epoch = 1 | iters = 1640 | loss: 1.46739 | acc: 0.46875
# Stats: epoch = 1 | iters = 1650 | loss: 1.50415 | acc: 0.5
# Stats: epoch = 1 | iters = 1660 | loss: 1.51901 | acc: 0.5
# Stats: epoch = 1 | iters = 1670 | loss: 1.41202 | acc: 0.5625
# Stats: epoch = 1 | iters = 1680 | loss: 1.43866 | acc: 0.53125
# Stats: epoch = 1 | iters = 1690 | loss: 1.38561 | acc: 0.5625
# Stats: epoch = 1 | iters = 1700 | loss: 1.55211 | acc: 0.5
# Stats: epoch = 1 | iters = 1710 | loss: 1.61349 | acc: 0.4375
# Stats: epoch = 1 | iters = 1720 | loss: 1.37298 | acc: 0.5625
# Stats: epoch = 1 | iters = 1730 | loss: 1.65576 | acc: 0.53125
# Stats: epoch = 1 | iters = 1740 | loss: 1.53809 | acc: 0.5
# Stats: epoch = 1 | iters = 1750 | loss: 1.52335 | acc: 0.53125
# Stats: epoch = 1 | iters = 1760 | loss: 1.51788 | acc: 0.53125
# Stats: epoch = 1 | iters = 1770 | loss: 1.53986 | acc: 0.5625
# Stats: epoch = 1 | iters = 1780 | loss: 1.43264 | acc: 0.5625
# Stats: epoch = 1 | iters = 1790 | loss: 1.5836 | acc: 0.53125
# Stats: epoch = 1 | iters = 1800 | loss: 1.41935 | acc: 0.65625
# Stats: epoch = 1 | iters = 1810 | loss: 1.27584 | acc: 0.59375
# Stats: epoch = 1 | iters = 1820 | loss: 1.26132 | acc: 0.625
# Stats: epoch = 1 | iters = 1830 | loss: 1.41892 | acc: 0.5
# Stats: epoch = 1 | iters = 1840 | loss: 1.30219 | acc: 0.53125
# Stats: epoch = 1 | iters = 1850 | loss: 1.71693 | acc: 0.4375
# Stats: epoch = 1 | iters = 1860 | loss: 1.3965 | acc: 0.53125
# Stats: epoch = 1 | iters = 1870 | loss: 1.31077 | acc: 0.5625
# Stats: epoch = 1 | iters = 1880 | loss: 1.01322 | acc: 0.71875
# Stats: epoch = 1 | iters = 1890 | loss: 1.43887 | acc: 0.5
# Stats: epoch = 1 | iters = 1900 | loss: 1.49513 | acc: 0.5625
# Stats: epoch = 1 | iters = 1910 | loss: 1.13082 | acc: 0.75
# Stats: epoch = 1 | iters = 1920 | loss: 1.53498 | acc: 0.46875
# Stats: epoch = 1 | iters = 1930 | loss: 1.38425 | acc: 0.5625
# Stats: epoch = 1 | iters = 1940 | loss: 1.47481 | acc: 0.53125
# Stats: epoch = 1 | iters = 1950 | loss: 1.43076 | acc: 0.59375
# Stats: epoch = 1 | iters = 1960 | loss: 1.37022 | acc: 0.59375
# Stats: epoch = 1 | iters = 1970 | loss: 1.86474 | acc: 0.4375
# Stats: epoch = 1 | iters = 1980 | loss: 1.41187 | acc: 0.5625
# Stats: epoch = 1 | iters = 1990 | loss: 1.54792 | acc: 0.625
# Stats: epoch = 1 | iters = 2000 | loss: 1.33222 | acc: 0.5625
# Stats: epoch = 1 | iters = 2010 | loss: 1.37638 | acc: 0.59375
# Stats: epoch = 1 | iters = 2020 | loss: 1.15032 | acc: 0.59375
# Stats: epoch = 1 | iters = 2030 | loss: 1.24334 | acc: 0.5625
# Stats: epoch = 1 | iters = 2040 | loss: 1.45467 | acc: 0.625
# Stats: epoch = 1 | iters = 2050 | loss: 1.42027 | acc: 0.59375
# Stats: epoch = 1 | iters = 2060 | loss: 1.3023 | acc: 0.59375
# Stats: epoch = 1 | iters = 2070 | loss: 1.16344 | acc: 0.65625
# Stats: epoch = 1 | iters = 2080 | loss: 1.38617 | acc: 0.5625
# Stats: epoch = 1 | iters = 2090 | loss: 1.33659 | acc: 0.625
# Stats: epoch = 1 | iters = 2100 | loss: 1.35376 | acc: 0.53125
# Stats: epoch = 1 | iters = 2110 | loss: 1.32242 | acc: 0.53125
# Stats: epoch = 1 | iters = 2120 | loss: 1.54029 | acc: 0.4375
# Stats: epoch = 1 | iters = 2130 | loss: 1.47031 | acc: 0.5625
# Stats: epoch = 1 | iters = 2140 | loss: 1.29637 | acc: 0.59375
# Stats: epoch = 1 | iters = 2150 | loss: 1.1621 | acc: 0.65625
# Stats: epoch = 1 | iters = 2160 | loss: 1.4202 | acc: 0.5625
# Stats: epoch = 1 | iters = 2170 | loss: 1.2688 | acc: 0.625
# Stats: epoch = 1 | iters = 2180 | loss: 1.43769 | acc: 0.59375
# Stats: epoch = 1 | iters = 2190 | loss: 1.48005 | acc: 0.5625
# Stats: epoch = 1 | iters = 2200 | loss: 1.67303 | acc: 0.46875
# Stats: epoch = 1 | iters = 2210 | loss: 1.55974 | acc: 0.5625
# Stats: epoch = 1 | iters = 2220 | loss: 1.27057 | acc: 0.59375
# Stats: epoch = 1 | iters = 2230 | loss: 1.53013 | acc: 0.4375
# Stats: epoch = 1 | iters = 2240 | loss: 1.30029 | acc: 0.59375
# Stats: epoch = 1 | iters = 2250 | loss: 1.21894 | acc: 0.46875
# Stats: epoch = 1 | iters = 2260 | loss: 1.25715 | acc: 0.625
# Stats: epoch = 1 | iters = 2270 | loss: 1.46907 | acc: 0.59375
# Stats: epoch = 1 | iters = 2280 | loss: 1.46972 | acc: 0.40625
# Stats: epoch = 1 | iters = 2290 | loss: 1.37465 | acc: 0.4375
# Stats: epoch = 1 | iters = 2300 | loss: 1.17761 | acc: 0.71875
# Stats: epoch = 1 | iters = 2310 | loss: 1.19148 | acc: 0.75
# Stats: epoch = 1 | iters = 2320 | loss: 1.11777 | acc: 0.75
# Stats: epoch = 1 | iters = 2330 | loss: 1.18496 | acc: 0.65625
# Stats: epoch = 1 | iters = 2340 | loss: 1.68198 | acc: 0.5
# Stats: epoch = 1 | iters = 2350 | loss: 1.31409 | acc: 0.59375
# Stats: epoch = 2 | iters = 2360 | loss: 1.53349 | acc: 0.46875
# Stats: epoch = 2 | iters = 2370 | loss: 1.27009 | acc: 0.59375
# Stats: epoch = 2 | iters = 2380 | loss: 1.18376 | acc: 0.65625
# Stats: epoch = 2 | iters = 2390 | loss: 1.26902 | acc: 0.59375
# Stats: epoch = 2 | iters = 2400 | loss: 0.948578 | acc: 0.625
# Stats: epoch = 2 | iters = 2410 | loss: 1.2535 | acc: 0.71875
# Stats: epoch = 2 | iters = 2420 | loss: 1.17459 | acc: 0.5625
# Stats: epoch = 2 | iters = 2430 | loss: 1.12425 | acc: 0.6875
# Stats: epoch = 2 | iters = 2440 | loss: 1.37392 | acc: 0.5
# Stats: epoch = 2 | iters = 2450 | loss: 1.05477 | acc: 0.65625
# Stats: epoch = 2 | iters = 2460 | loss: 1.21509 | acc: 0.59375
# Stats: epoch = 2 | iters = 2470 | loss: 0.905417 | acc: 0.6875
# Stats: epoch = 2 | iters = 2480 | loss: 1.35501 | acc: 0.53125
# Stats: epoch = 2 | iters = 2490 | loss: 1.24583 | acc: 0.65625
# Stats: epoch = 2 | iters = 2500 | loss: 1.03966 | acc: 0.65625
# Stats: epoch = 2 | iters = 2510 | loss: 1.28561 | acc: 0.625
# Stats: epoch = 2 | iters = 2520 | loss: 1.35249 | acc: 0.6875
# Stats: epoch = 2 | iters = 2530 | loss: 1.1092 | acc: 0.71875
# Stats: epoch = 2 | iters = 2540 | loss: 1.2931 | acc: 0.5625
# Stats: epoch = 2 | iters = 2550 | loss: 1.31603 | acc: 0.53125
# Stats: epoch = 2 | iters = 2560 | loss: 1.08059 | acc: 0.71875
# Stats: epoch = 2 | iters = 2570 | loss: 1.18148 | acc: 0.65625
# Stats: epoch = 2 | iters = 2580 | loss: 0.817961 | acc: 0.8125
# Stats: epoch = 2 | iters = 2590 | loss: 1.36127 | acc: 0.46875
# Stats: epoch = 2 | iters = 2600 | loss: 1.52993 | acc: 0.4375
# Stats: epoch = 2 | iters = 2610 | loss: 1.29049 | acc: 0.6875
# Stats: epoch = 2 | iters = 2620 | loss: 1.09489 | acc: 0.625
# Stats: epoch = 2 | iters = 2630 | loss: 1.1456 | acc: 0.5625
# Stats: epoch = 2 | iters = 2640 | loss: 1.29279 | acc: 0.65625
# Stats: epoch = 2 | iters = 2650 | loss: 1.28522 | acc: 0.71875
# Stats: epoch = 2 | iters = 2660 | loss: 1.24177 | acc: 0.5625
# Stats: epoch = 2 | iters = 2670 | loss: 1.10445 | acc: 0.65625
# Stats: epoch = 2 | iters = 2680 | loss: 1.26872 | acc: 0.625
# Stats: epoch = 2 | iters = 2690 | loss: 1.08077 | acc: 0.59375
# Stats: epoch = 2 | iters = 2700 | loss: 1.17452 | acc: 0.625
# Stats: epoch = 2 | iters = 2710 | loss: 1.20234 | acc: 0.65625
# Stats: epoch = 2 | iters = 2720 | loss: 1.20359 | acc: 0.625
# Stats: epoch = 2 | iters = 2730 | loss: 1.03625 | acc: 0.71875
# Stats: epoch = 2 | iters = 2740 | loss: 1.51265 | acc: 0.46875
# Stats: epoch = 2 | iters = 2750 | loss: 1.3383 | acc: 0.625
# Stats: epoch = 2 | iters = 2760 | loss: 1.32525 | acc: 0.5625
# Stats: epoch = 2 | iters = 2770 | loss: 1.20463 | acc: 0.65625
# Stats: epoch = 2 | iters = 2780 | loss: 1.21698 | acc: 0.59375
# Stats: epoch = 2 | iters = 2790 | loss: 0.928509 | acc: 0.78125
# Stats: epoch = 2 | iters = 2800 | loss: 1.29959 | acc: 0.53125
# Stats: epoch = 2 | iters = 2810 | loss: 1.54525 | acc: 0.53125
# Stats: epoch = 2 | iters = 2820 | loss: 0.979172 | acc: 0.71875
# Stats: epoch = 2 | iters = 2830 | loss: 1.04158 | acc: 0.75
# Stats: epoch = 2 | iters = 2840 | loss: 1.37451 | acc: 0.53125
# Stats: epoch = 2 | iters = 2850 | loss: 1.39261 | acc: 0.59375
# Stats: epoch = 2 | iters = 2860 | loss: 1.08606 | acc: 0.6875
# Stats: epoch = 2 | iters = 2870 | loss: 1.02806 | acc: 0.71875
# Stats: epoch = 2 | iters = 2880 | loss: 1.12588 | acc: 0.65625
# Stats: epoch = 2 | iters = 2890 | loss: 1.40888 | acc: 0.46875
# Stats: epoch = 2 | iters = 2900 | loss: 0.995156 | acc: 0.71875
# Stats: epoch = 2 | iters = 2910 | loss: 1.21354 | acc: 0.75
# Stats: epoch = 2 | iters = 2920 | loss: 1.43525 | acc: 0.5
# Stats: epoch = 2 | iters = 2930 | loss: 1.23893 | acc: 0.5625
# Stats: epoch = 2 | iters = 2940 | loss: 0.907462 | acc: 0.75
# Stats: epoch = 2 | iters = 2950 | loss: 1.16219 | acc: 0.625
# Stats: epoch = 2 | iters = 2960 | loss: 1.14454 | acc: 0.6875
# Stats: epoch = 2 | iters = 2970 | loss: 1.44665 | acc: 0.46875
# Stats: epoch = 2 | iters = 2980 | loss: 1.18202 | acc: 0.65625
# Stats: epoch = 2 | iters = 2990 | loss: 1.13773 | acc: 0.65625
# Stats: epoch = 2 | iters = 3000 | loss: 1.34185 | acc: 0.5625
# Stats: epoch = 2 | iters = 3010 | loss: 1.00276 | acc: 0.71875
# Stats: epoch = 2 | iters = 3020 | loss: 1.0928 | acc: 0.59375
# Stats: epoch = 2 | iters = 3030 | loss: 1.06758 | acc: 0.6875
# Stats: epoch = 2 | iters = 3040 | loss: 1.1909 | acc: 0.5625
# Stats: epoch = 2 | iters = 3050 | loss: 1.22362 | acc: 0.5625
# Stats: epoch = 2 | iters = 3060 | loss: 1.3168 | acc: 0.6875
# Stats: epoch = 2 | iters = 3070 | loss: 1.28106 | acc: 0.625
# Stats: epoch = 2 | iters = 3080 | loss: 1.1092 | acc: 0.625
# Stats: epoch = 2 | iters = 3090 | loss: 1.2947 | acc: 0.65625
# Stats: epoch = 2 | iters = 3100 | loss: 1.30797 | acc: 0.53125
# Stats: epoch = 2 | iters = 3110 | loss: 1.00608 | acc: 0.78125
# Stats: epoch = 2 | iters = 3120 | loss: 1.24958 | acc: 0.5625
# Stats: epoch = 2 | iters = 3130 | loss: 1.12068 | acc: 0.71875
# Stats: epoch = 2 | iters = 3140 | loss: 1.40497 | acc: 0.46875
# Stats: epoch = 2 | iters = 3150 | loss: 1.12142 | acc: 0.625
# Stats: epoch = 2 | iters = 3160 | loss: 1.18223 | acc: 0.75
# Stats: epoch = 2 | iters = 3170 | loss: 1.31259 | acc: 0.625
# Stats: epoch = 2 | iters = 3180 | loss: 1.11748 | acc: 0.625
# Stats: epoch = 2 | iters = 3190 | loss: 1.39491 | acc: 0.46875
# Stats: epoch = 2 | iters = 3200 | loss: 1.2732 | acc: 0.65625
# Stats: epoch = 2 | iters = 3210 | loss: 1.07096 | acc: 0.625
# Stats: epoch = 2 | iters = 3220 | loss: 1.19207 | acc: 0.65625
# Stats: epoch = 2 | iters = 3230 | loss: 1.39599 | acc: 0.59375
# Stats: epoch = 2 | iters = 3240 | loss: 1.0804 | acc: 0.6875
# Stats: epoch = 2 | iters = 3250 | loss: 0.945774 | acc: 0.78125
# Stats: epoch = 2 | iters = 3260 | loss: 1.0887 | acc: 0.53125
# Stats: epoch = 2 | iters = 3270 | loss: 0.838924 | acc: 0.8125
# Stats: epoch = 2 | iters = 3280 | loss: 1.04732 | acc: 0.65625
# Stats: epoch = 2 | iters = 3290 | loss: 1.09563 | acc: 0.59375
# Stats: epoch = 2 | iters = 3300 | loss: 1.18696 | acc: 0.65625
# Stats: epoch = 2 | iters = 3310 | loss: 0.805371 | acc: 0.75
# Stats: epoch = 2 | iters = 3320 | loss: 1.18812 | acc: 0.59375
# Stats: epoch = 2 | iters = 3330 | loss: 0.994284 | acc: 0.75
# Stats: epoch = 2 | iters = 3340 | loss: 1.21393 | acc: 0.6875
# Stats: epoch = 2 | iters = 3350 | loss: 1.11042 | acc: 0.71875
# Stats: epoch = 2 | iters = 3360 | loss: 1.16356 | acc: 0.65625
# Stats: epoch = 2 | iters = 3370 | loss: 1.2143 | acc: 0.59375
# Stats: epoch = 2 | iters = 3380 | loss: 1.0663 | acc: 0.65625
# Stats: epoch = 2 | iters = 3390 | loss: 0.845454 | acc: 0.78125
# Stats: epoch = 2 | iters = 3400 | loss: 1.32065 | acc: 0.59375
# Stats: epoch = 2 | iters = 3410 | loss: 1.08996 | acc: 0.6875
# Stats: epoch = 2 | iters = 3420 | loss: 1.47528 | acc: 0.53125
# Stats: epoch = 2 | iters = 3430 | loss: 1.0998 | acc: 0.65625
# Stats: epoch = 2 | iters = 3440 | loss: 1.19272 | acc: 0.625
# Stats: epoch = 2 | iters = 3450 | loss: 0.966958 | acc: 0.75
# Stats: epoch = 2 | iters = 3460 | loss: 1.46611 | acc: 0.46875
# Stats: epoch = 2 | iters = 3470 | loss: 0.976191 | acc: 0.75
# Stats: epoch = 2 | iters = 3480 | loss: 1.18377 | acc: 0.71875
# Stats: epoch = 2 | iters = 3490 | loss: 1.20575 | acc: 0.59375
# Stats: epoch = 2 | iters = 3500 | loss: 1.17996 | acc: 0.65625
# Stats: epoch = 2 | iters = 3510 | loss: 0.967652 | acc: 0.78125
# Stats: epoch = 2 | iters = 3520 | loss: 0.795411 | acc: 0.78125
# Stats: epoch = 2 | iters = 3530 | loss: 1.2837 | acc: 0.5625
# Stats: epoch = 3 | iters = 3540 | loss: 1.1699 | acc: 0.59375
# Stats: epoch = 3 | iters = 3550 | loss: 1.24472 | acc: 0.59375
# Stats: epoch = 3 | iters = 3560 | loss: 1.13314 | acc: 0.625
# Stats: epoch = 3 | iters = 3570 | loss: 1.28248 | acc: 0.59375
# Stats: epoch = 3 | iters = 3580 | loss: 0.822762 | acc: 0.75
# Stats: epoch = 3 | iters = 3590 | loss: 1.00533 | acc: 0.78125
# Stats: epoch = 3 | iters = 3600 | loss: 1.02955 | acc: 0.6875
# Stats: epoch = 3 | iters = 3610 | loss: 1.28949 | acc: 0.5625
# Stats: epoch = 3 | iters = 3620 | loss: 1.04113 | acc: 0.6875
# Stats: epoch = 3 | iters = 3630 | loss: 0.971155 | acc: 0.625
# Stats: epoch = 3 | iters = 3640 | loss: 1.08389 | acc: 0.6875
# Stats: epoch = 3 | iters = 3650 | loss: 1.16554 | acc: 0.6875
# Stats: epoch = 3 | iters = 3660 | loss: 1.06901 | acc: 0.625
# Stats: epoch = 3 | iters = 3670 | loss: 0.78985 | acc: 0.78125
# Stats: epoch = 3 | iters = 3680 | loss: 0.821964 | acc: 0.8125
# Stats: epoch = 3 | iters = 3690 | loss: 1.27426 | acc: 0.6875
# Stats: epoch = 3 | iters = 3700 | loss: 1.29167 | acc: 0.59375
# Stats: epoch = 3 | iters = 3710 | loss: 1.06111 | acc: 0.6875
# Stats: epoch = 3 | iters = 3720 | loss: 0.787035 | acc: 0.75
# Stats: epoch = 3 | iters = 3730 | loss: 1.16578 | acc: 0.71875
# Stats: epoch = 3 | iters = 3740 | loss: 1.0648 | acc: 0.75
# Stats: epoch = 3 | iters = 3750 | loss: 0.994416 | acc: 0.71875
# Stats: epoch = 3 | iters = 3760 | loss: 1.3251 | acc: 0.59375
# Stats: epoch = 3 | iters = 3770 | loss: 0.884394 | acc: 0.6875
# Stats: epoch = 3 | iters = 3780 | loss: 0.764292 | acc: 0.8125
# Stats: epoch = 3 | iters = 3790 | loss: 0.877382 | acc: 0.6875
# Stats: epoch = 3 | iters = 3800 | loss: 1.15949 | acc: 0.71875
# Stats: epoch = 3 | iters = 3810 | loss: 0.811157 | acc: 0.875
# Stats: epoch = 3 | iters = 3820 | loss: 0.879477 | acc: 0.75
# Stats: epoch = 3 | iters = 3830 | loss: 0.831592 | acc: 0.8125
# Stats: epoch = 3 | iters = 3840 | loss: 1.14626 | acc: 0.625
# Stats: epoch = 3 | iters = 3850 | loss: 1.00327 | acc: 0.75
# Stats: epoch = 3 | iters = 3860 | loss: 0.802435 | acc: 0.78125
# Stats: epoch = 3 | iters = 3870 | loss: 1.0754 | acc: 0.71875
# Stats: epoch = 3 | iters = 3880 | loss: 0.910591 | acc: 0.75
# Stats: epoch = 3 | iters = 3890 | loss: 1.25553 | acc: 0.6875
# Stats: epoch = 3 | iters = 3900 | loss: 1.06574 | acc: 0.6875
# Stats: epoch = 3 | iters = 3910 | loss: 1.28201 | acc: 0.625
# Stats: epoch = 3 | iters = 3920 | loss: 0.949569 | acc: 0.6875
# Stats: epoch = 3 | iters = 3930 | loss: 0.925036 | acc: 0.78125
# Stats: epoch = 3 | iters = 3940 | loss: 1.17136 | acc: 0.625
# Stats: epoch = 3 | iters = 3950 | loss: 0.840541 | acc: 0.6875
# Stats: epoch = 3 | iters = 3960 | loss: 1.14234 | acc: 0.71875
# Stats: epoch = 3 | iters = 3970 | loss: 0.994235 | acc: 0.78125
# Stats: epoch = 3 | iters = 3980 | loss: 1.23996 | acc: 0.5625
# Stats: epoch = 3 | iters = 3990 | loss: 1.17322 | acc: 0.65625
# Stats: epoch = 3 | iters = 4000 | loss: 1.01632 | acc: 0.65625
# Stats: epoch = 3 | iters = 4010 | loss: 0.707015 | acc: 0.8125
# Stats: epoch = 3 | iters = 4020 | loss: 1.03752 | acc: 0.65625
# Stats: epoch = 3 | iters = 4030 | loss: 0.890394 | acc: 0.71875
# Stats: epoch = 3 | iters = 4040 | loss: 1.17374 | acc: 0.625
# Stats: epoch = 3 | iters = 4050 | loss: 0.863821 | acc: 0.78125
# Stats: epoch = 3 | iters = 4060 | loss: 0.768982 | acc: 0.875
# Stats: epoch = 3 | iters = 4070 | loss: 1.01746 | acc: 0.65625
# Stats: epoch = 3 | iters = 4080 | loss: 1.05406 | acc: 0.65625
# Stats: epoch = 3 | iters = 4090 | loss: 0.755411 | acc: 0.8125
# Stats: epoch = 3 | iters = 4100 | loss: 0.796328 | acc: 0.6875
# Stats: epoch = 3 | iters = 4110 | loss: 1.01986 | acc: 0.75
# Stats: epoch = 3 | iters = 4120 | loss: 0.898565 | acc: 0.625
# Stats: epoch = 3 | iters = 4130 | loss: 1.41241 | acc: 0.5
# Stats: epoch = 3 | iters = 4140 | loss: 1.09427 | acc: 0.75
# Stats: epoch = 3 | iters = 4150 | loss: 1.03739 | acc: 0.6875
# Stats: epoch = 3 | iters = 4160 | loss: 0.802456 | acc: 0.875
# Stats: epoch = 3 | iters = 4170 | loss: 1.09233 | acc: 0.65625
# Stats: epoch = 3 | iters = 4180 | loss: 1.23888 | acc: 0.53125
# Stats: epoch = 3 | iters = 4190 | loss: 0.951353 | acc: 0.75
# Stats: epoch = 3 | iters = 4200 | loss: 1.01871 | acc: 0.625
# Stats: epoch = 3 | iters = 4210 | loss: 0.886891 | acc: 0.71875
# Stats: epoch = 3 | iters = 4220 | loss: 0.930128 | acc: 0.75
# Stats: epoch = 3 | iters = 4230 | loss: 1.21048 | acc: 0.59375
# Stats: epoch = 3 | iters = 4240 | loss: 1.23011 | acc: 0.5625
# Stats: epoch = 3 | iters = 4250 | loss: 1.06429 | acc: 0.625
# Stats: epoch = 3 | iters = 4260 | loss: 1.12644 | acc: 0.59375
# Stats: epoch = 3 | iters = 4270 | loss: 1.13611 | acc: 0.625
# Stats: epoch = 3 | iters = 4280 | loss: 1.06236 | acc: 0.65625
# Stats: epoch = 3 | iters = 4290 | loss: 0.921723 | acc: 0.71875
# Stats: epoch = 3 | iters = 4300 | loss: 1.05817 | acc: 0.65625
# Stats: epoch = 3 | iters = 4310 | loss: 1.02577 | acc: 0.71875
# Stats: epoch = 3 | iters = 4320 | loss: 1.01555 | acc: 0.71875
# Stats: epoch = 3 | iters = 4330 | loss: 1.01274 | acc: 0.71875
# Stats: epoch = 3 | iters = 4340 | loss: 0.838751 | acc: 0.75
# Stats: epoch = 3 | iters = 4350 | loss: 1.07809 | acc: 0.75
# Stats: epoch = 3 | iters = 4360 | loss: 0.994281 | acc: 0.625
# Stats: epoch = 3 | iters = 4370 | loss: 0.934624 | acc: 0.75
# Stats: epoch = 3 | iters = 4380 | loss: 0.820444 | acc: 0.75
# Stats: epoch = 3 | iters = 4390 | loss: 0.769666 | acc: 0.84375
# Stats: epoch = 3 | iters = 4400 | loss: 1.14291 | acc: 0.65625
# Stats: epoch = 3 | iters = 4410 | loss: 1.07314 | acc: 0.625
# Stats: epoch = 3 | iters = 4420 | loss: 0.817976 | acc: 0.8125
# Stats: epoch = 3 | iters = 4430 | loss: 1.02053 | acc: 0.71875
# Stats: epoch = 3 | iters = 4440 | loss: 1.08038 | acc: 0.5625
# Stats: epoch = 3 | iters = 4450 | loss: 1.17207 | acc: 0.625
# Stats: epoch = 3 | iters = 4460 | loss: 0.841465 | acc: 0.75
# Stats: epoch = 3 | iters = 4470 | loss: 1.06122 | acc: 0.6875
# Stats: epoch = 3 | iters = 4480 | loss: 1.14608 | acc: 0.625
# Stats: epoch = 3 | iters = 4490 | loss: 1.06717 | acc: 0.71875
# Stats: epoch = 3 | iters = 4500 | loss: 1.3412 | acc: 0.65625
# Stats: epoch = 3 | iters = 4510 | loss: 0.856744 | acc: 0.71875
# Stats: epoch = 3 | iters = 4520 | loss: 1.14133 | acc: 0.625
# Stats: epoch = 3 | iters = 4530 | loss: 1.14295 | acc: 0.65625
# Stats: epoch = 3 | iters = 4540 | loss: 1.18055 | acc: 0.59375
# Stats: epoch = 3 | iters = 4550 | loss: 0.935512 | acc: 0.71875
# Stats: epoch = 3 | iters = 4560 | loss: 0.997784 | acc: 0.6875
# Stats: epoch = 3 | iters = 4570 | loss: 0.781252 | acc: 0.84375
# Stats: epoch = 3 | iters = 4580 | loss: 1.19633 | acc: 0.625
# Stats: epoch = 3 | iters = 4590 | loss: 1.23133 | acc: 0.5625
# Stats: epoch = 3 | iters = 4600 | loss: 1.16759 | acc: 0.6875
# Stats: epoch = 3 | iters = 4610 | loss: 0.873268 | acc: 0.75
# Stats: epoch = 3 | iters = 4620 | loss: 1.02656 | acc: 0.71875
# Stats: epoch = 3 | iters = 4630 | loss: 1.1264 | acc: 0.6875
# Stats: epoch = 3 | iters = 4640 | loss: 0.912055 | acc: 0.71875
# Stats: epoch = 3 | iters = 4650 | loss: 0.574914 | acc: 0.875
# Stats: epoch = 3 | iters = 4660 | loss: 1.01982 | acc: 0.59375
# Stats: epoch = 3 | iters = 4670 | loss: 0.930084 | acc: 0.71875
# Stats: epoch = 3 | iters = 4680 | loss: 0.966297 | acc: 0.6875
# Stats: epoch = 3 | iters = 4690 | loss: 1.06979 | acc: 0.65625
# Stats: epoch = 3 | iters = 4700 | loss: 1.01469 | acc: 0.625
# Stats: epoch = 4 | iters = 4710 | loss: 0.918499 | acc: 0.78125
# Stats: epoch = 4 | iters = 4720 | loss: 1.00534 | acc: 0.6875
# Stats: epoch = 4 | iters = 4730 | loss: 0.950298 | acc: 0.78125
# Stats: epoch = 4 | iters = 4740 | loss: 0.961754 | acc: 0.75
# Stats: epoch = 4 | iters = 4750 | loss: 0.801753 | acc: 0.75
# Stats: epoch = 4 | iters = 4760 | loss: 1.02136 | acc: 0.65625
# Stats: epoch = 4 | iters = 4770 | loss: 0.834566 | acc: 0.71875
# Stats: epoch = 4 | iters = 4780 | loss: 0.693244 | acc: 0.84375
# Stats: epoch = 4 | iters = 4790 | loss: 0.813705 | acc: 0.75
# Stats: epoch = 4 | iters = 4800 | loss: 1.2501 | acc: 0.6875
# Stats: epoch = 4 | iters = 4810 | loss: 0.823086 | acc: 0.78125
# Stats: epoch = 4 | iters = 4820 | loss: 0.618624 | acc: 0.90625
# Stats: epoch = 4 | iters = 4830 | loss: 0.963521 | acc: 0.65625
# Stats: epoch = 4 | iters = 4840 | loss: 1.38455 | acc: 0.5625
# Stats: epoch = 4 | iters = 4850 | loss: 1.37266 | acc: 0.59375
# Stats: epoch = 4 | iters = 4860 | loss: 0.679661 | acc: 0.8125
# Stats: epoch = 4 | iters = 4870 | loss: 1.0703 | acc: 0.71875
# Stats: epoch = 4 | iters = 4880 | loss: 1.06347 | acc: 0.65625
# Stats: epoch = 4 | iters = 4890 | loss: 1.0603 | acc: 0.65625
# Stats: epoch = 4 | iters = 4900 | loss: 1.21546 | acc: 0.6875
# Stats: epoch = 4 | iters = 4910 | loss: 0.997028 | acc: 0.78125
# Stats: epoch = 4 | iters = 4920 | loss: 0.94917 | acc: 0.75
# Stats: epoch = 4 | iters = 4930 | loss: 1.06661 | acc: 0.6875
# Stats: epoch = 4 | iters = 4940 | loss: 0.920371 | acc: 0.78125
# Stats: epoch = 4 | iters = 4950 | loss: 0.925372 | acc: 0.75
# Stats: epoch = 4 | iters = 4960 | loss: 1.20561 | acc: 0.59375
# Stats: epoch = 4 | iters = 4970 | loss: 0.931894 | acc: 0.75
# Stats: epoch = 4 | iters = 4980 | loss: 1.04119 | acc: 0.75
# Stats: epoch = 4 | iters = 4990 | loss: 0.837788 | acc: 0.75
# Stats: epoch = 4 | iters = 5000 | loss: 0.704091 | acc: 0.84375
# Stats: epoch = 4 | iters = 5010 | loss: 0.882071 | acc: 0.75
# Stats: epoch = 4 | iters = 5020 | loss: 0.720537 | acc: 0.84375
# Stats: epoch = 4 | iters = 5030 | loss: 0.864717 | acc: 0.65625
# Stats: epoch = 4 | iters = 5040 | loss: 1.13712 | acc: 0.65625
# Stats: epoch = 4 | iters = 5050 | loss: 1.02299 | acc: 0.75
# Stats: epoch = 4 | iters = 5060 | loss: 1.1 | acc: 0.75
# Stats: epoch = 4 | iters = 5070 | loss: 0.611126 | acc: 0.84375
# Stats: epoch = 4 | iters = 5080 | loss: 1.0944 | acc: 0.71875
# Stats: epoch = 4 | iters = 5090 | loss: 1.17137 | acc: 0.65625
# Stats: epoch = 4 | iters = 5100 | loss: 1.21095 | acc: 0.5625
# Stats: epoch = 4 | iters = 5110 | loss: 0.850118 | acc: 0.75
# Stats: epoch = 4 | iters = 5120 | loss: 0.858684 | acc: 0.6875
# Stats: epoch = 4 | iters = 5130 | loss: 0.737094 | acc: 0.875
# Stats: epoch = 4 | iters = 5140 | loss: 0.898134 | acc: 0.75
# Stats: epoch = 4 | iters = 5150 | loss: 1.04877 | acc: 0.78125
# Stats: epoch = 4 | iters = 5160 | loss: 0.764096 | acc: 0.78125
# Stats: epoch = 4 | iters = 5170 | loss: 1.00299 | acc: 0.6875
# Stats: epoch = 4 | iters = 5180 | loss: 0.645383 | acc: 0.8125
# Stats: epoch = 4 | iters = 5190 | loss: 0.891959 | acc: 0.75
# Stats: epoch = 4 | iters = 5200 | loss: 0.939762 | acc: 0.71875
# Stats: epoch = 4 | iters = 5210 | loss: 1.18299 | acc: 0.59375
# Stats: epoch = 4 | iters = 5220 | loss: 1.15075 | acc: 0.59375
# Stats: epoch = 4 | iters = 5230 | loss: 0.971263 | acc: 0.6875
# Stats: epoch = 4 | iters = 5240 | loss: 1.02025 | acc: 0.65625
# Stats: epoch = 4 | iters = 5250 | loss: 1.01658 | acc: 0.75
# Stats: epoch = 4 | iters = 5260 | loss: 1.04438 | acc: 0.5625
# Stats: epoch = 4 | iters = 5270 | loss: 0.816896 | acc: 0.71875
# Stats: epoch = 4 | iters = 5280 | loss: 0.806726 | acc: 0.78125
# Stats: epoch = 4 | iters = 5290 | loss: 0.79882 | acc: 0.8125
# Stats: epoch = 4 | iters = 5300 | loss: 1.04027 | acc: 0.75
# Stats: epoch = 4 | iters = 5310 | loss: 0.550107 | acc: 0.84375
# Stats: epoch = 4 | iters = 5320 | loss: 0.768547 | acc: 0.78125
# Stats: epoch = 4 | iters = 5330 | loss: 0.93147 | acc: 0.65625
# Stats: epoch = 4 | iters = 5340 | loss: 1.08663 | acc: 0.71875
# Stats: epoch = 4 | iters = 5350 | loss: 0.772164 | acc: 0.8125
# Stats: epoch = 4 | iters = 5360 | loss: 0.851648 | acc: 0.78125
# Stats: epoch = 4 | iters = 5370 | loss: 1.06678 | acc: 0.65625
# Stats: epoch = 4 | iters = 5380 | loss: 0.741275 | acc: 0.84375
# Stats: epoch = 4 | iters = 5390 | loss: 1.05145 | acc: 0.78125
# Stats: epoch = 4 | iters = 5400 | loss: 0.735339 | acc: 0.8125
# Stats: epoch = 4 | iters = 5410 | loss: 0.859123 | acc: 0.6875
# Stats: epoch = 4 | iters = 5420 | loss: 0.927419 | acc: 0.6875
# Stats: epoch = 4 | iters = 5430 | loss: 1.0249 | acc: 0.71875
# Stats: epoch = 4 | iters = 5440 | loss: 0.752275 | acc: 0.8125
# Stats: epoch = 4 | iters = 5450 | loss: 1.09683 | acc: 0.6875
# Stats: epoch = 4 | iters = 5460 | loss: 0.995488 | acc: 0.78125
# Stats: epoch = 4 | iters = 5470 | loss: 0.951512 | acc: 0.75
# Stats: epoch = 4 | iters = 5480 | loss: 0.982651 | acc: 0.8125
# Stats: epoch = 4 | iters = 5490 | loss: 1.10788 | acc: 0.65625
# Stats: epoch = 4 | iters = 5500 | loss: 1.08109 | acc: 0.59375
# Stats: epoch = 4 | iters = 5510 | loss: 0.960276 | acc: 0.71875
# Stats: epoch = 4 | iters = 5520 | loss: 0.870915 | acc: 0.75
# Stats: epoch = 4 | iters = 5530 | loss: 0.796456 | acc: 0.71875
# Stats: epoch = 4 | iters = 5540 | loss: 1.27696 | acc: 0.6875
# Stats: epoch = 4 | iters = 5550 | loss: 0.720339 | acc: 0.8125
# Stats: epoch = 4 | iters = 5560 | loss: 0.993502 | acc: 0.59375
# Stats: epoch = 4 | iters = 5570 | loss: 0.976817 | acc: 0.6875
# Stats: epoch = 4 | iters = 5580 | loss: 0.643531 | acc: 0.875
# Stats: epoch = 4 | iters = 5590 | loss: 0.800542 | acc: 0.625
# Stats: epoch = 4 | iters = 5600 | loss: 1.06738 | acc: 0.59375
# Stats: epoch = 4 | iters = 5610 | loss: 0.797698 | acc: 0.78125
# Stats: epoch = 4 | iters = 5620 | loss: 0.922914 | acc: 0.71875
# Stats: epoch = 4 | iters = 5630 | loss: 0.783468 | acc: 0.78125
# Stats: epoch = 4 | iters = 5640 | loss: 1.06291 | acc: 0.5625
# Stats: epoch = 4 | iters = 5650 | loss: 0.583 | acc: 0.90625
# Stats: epoch = 4 | iters = 5660 | loss: 0.828398 | acc: 0.8125
# Stats: epoch = 4 | iters = 5670 | loss: 0.780216 | acc: 0.8125
# Stats: epoch = 4 | iters = 5680 | loss: 1.10353 | acc: 0.71875
# Stats: epoch = 4 | iters = 5690 | loss: 0.760174 | acc: 0.8125
# Stats: epoch = 4 | iters = 5700 | loss: 0.847117 | acc: 0.78125
# Stats: epoch = 4 | iters = 5710 | loss: 0.807283 | acc: 0.75
# Stats: epoch = 4 | iters = 5720 | loss: 0.910468 | acc: 0.75
# Stats: epoch = 4 | iters = 5730 | loss: 0.821794 | acc: 0.84375
# Stats: epoch = 4 | iters = 5740 | loss: 1.01523 | acc: 0.59375
# Stats: epoch = 4 | iters = 5750 | loss: 0.662673 | acc: 0.8125
# Stats: epoch = 4 | iters = 5760 | loss: 0.74228 | acc: 0.78125
# Stats: epoch = 4 | iters = 5770 | loss: 0.702839 | acc: 0.8125
# Stats: epoch = 4 | iters = 5780 | loss: 0.843314 | acc: 0.8125
# Stats: epoch = 4 | iters = 5790 | loss: 0.797338 | acc: 0.75
# Stats: epoch = 4 | iters = 5800 | loss: 0.956218 | acc: 0.6875
# Stats: epoch = 4 | iters = 5810 | loss: 0.958473 | acc: 0.75
# Stats: epoch = 4 | iters = 5820 | loss: 0.813979 | acc: 0.78125
# Stats: epoch = 4 | iters = 5830 | loss: 0.996283 | acc: 0.59375
# Stats: epoch = 4 | iters = 5840 | loss: 0.997516 | acc: 0.625
# Stats: epoch = 4 | iters = 5850 | loss: 0.588701 | acc: 0.875
# Stats: epoch = 4 | iters = 5860 | loss: 0.802856 | acc: 0.78125
# Stats: epoch = 4 | iters = 5870 | loss: 1.09167 | acc: 0.6875
# Stats: epoch = 4 | iters = 5880 | loss: 0.57412 | acc: 0.84375
# Stats: epoch = 5 | iters = 5890 | loss: 0.855315 | acc: 0.8125
# Stats: epoch = 5 | iters = 5900 | loss: 0.554037 | acc: 0.8125
# Stats: epoch = 5 | iters = 5910 | loss: 1.1472 | acc: 0.625
# Stats: epoch = 5 | iters = 5920 | loss: 0.756379 | acc: 0.8125
# Stats: epoch = 5 | iters = 5930 | loss: 0.671016 | acc: 0.8125
# Stats: epoch = 5 | iters = 5940 | loss: 1.10739 | acc: 0.71875
# Stats: epoch = 5 | iters = 5950 | loss: 1.10848 | acc: 0.65625
# Stats: epoch = 5 | iters = 5960 | loss: 0.804582 | acc: 0.75
# Stats: epoch = 5 | iters = 5970 | loss: 1.26448 | acc: 0.625
# Stats: epoch = 5 | iters = 5980 | loss: 0.995579 | acc: 0.625
# Stats: epoch = 5 | iters = 5990 | loss: 0.921591 | acc: 0.8125
# Stats: epoch = 5 | iters = 6000 | loss: 0.917427 | acc: 0.75
# Stats: epoch = 5 | iters = 6010 | loss: 0.823849 | acc: 0.71875
# Stats: epoch = 5 | iters = 6020 | loss: 0.628965 | acc: 0.8125
# Stats: epoch = 5 | iters = 6030 | loss: 0.823143 | acc: 0.8125
# Stats: epoch = 5 | iters = 6040 | loss: 1.08382 | acc: 0.75
# Stats: epoch = 5 | iters = 6050 | loss: 0.77608 | acc: 0.78125
# Stats: epoch = 5 | iters = 6060 | loss: 0.649744 | acc: 0.90625
# Stats: epoch = 5 | iters = 6070 | loss: 1.04204 | acc: 0.53125
# Stats: epoch = 5 | iters = 6080 | loss: 0.571753 | acc: 0.90625
# Stats: epoch = 5 | iters = 6090 | loss: 0.729551 | acc: 0.8125
# Stats: epoch = 5 | iters = 6100 | loss: 0.843637 | acc: 0.8125
# Stats: epoch = 5 | iters = 6110 | loss: 0.943985 | acc: 0.78125
# Stats: epoch = 5 | iters = 6120 | loss: 0.746603 | acc: 0.84375
# Stats: epoch = 5 | iters = 6130 | loss: 1.01989 | acc: 0.625
# Stats: epoch = 5 | iters = 6140 | loss: 0.907416 | acc: 0.71875
# Stats: epoch = 5 | iters = 6150 | loss: 0.666655 | acc: 0.75
# Stats: epoch = 5 | iters = 6160 | loss: 0.944136 | acc: 0.6875
# Stats: epoch = 5 | iters = 6170 | loss: 0.700889 | acc: 0.78125
# Stats: epoch = 5 | iters = 6180 | loss: 1.02382 | acc: 0.59375
# Stats: epoch = 5 | iters = 6190 | loss: 0.967236 | acc: 0.6875
# Stats: epoch = 5 | iters = 6200 | loss: 0.861025 | acc: 0.78125
# Stats: epoch = 5 | iters = 6210 | loss: 0.98172 | acc: 0.75
# Stats: epoch = 5 | iters = 6220 | loss: 0.960931 | acc: 0.71875
# Stats: epoch = 5 | iters = 6230 | loss: 0.873447 | acc: 0.625
# Stats: epoch = 5 | iters = 6240 | loss: 1.11845 | acc: 0.75
# Stats: epoch = 5 | iters = 6250 | loss: 0.594193 | acc: 0.84375
# Stats: epoch = 5 | iters = 6260 | loss: 0.792199 | acc: 0.8125
# Stats: epoch = 5 | iters = 6270 | loss: 0.531885 | acc: 0.875
# Stats: epoch = 5 | iters = 6280 | loss: 0.844147 | acc: 0.78125
# Stats: epoch = 5 | iters = 6290 | loss: 1.05631 | acc: 0.75
# Stats: epoch = 5 | iters = 6300 | loss: 0.722778 | acc: 0.8125
# Stats: epoch = 5 | iters = 6310 | loss: 0.695901 | acc: 0.71875
# Stats: epoch = 5 | iters = 6320 | loss: 0.79801 | acc: 0.71875
# Stats: epoch = 5 | iters = 6330 | loss: 0.582045 | acc: 0.8125
# Stats: epoch = 5 | iters = 6340 | loss: 0.956178 | acc: 0.75
# Stats: epoch = 5 | iters = 6350 | loss: 0.97768 | acc: 0.625
# Stats: epoch = 5 | iters = 6360 | loss: 0.756051 | acc: 0.75
# Stats: epoch = 5 | iters = 6370 | loss: 0.599023 | acc: 0.875
# Stats: epoch = 5 | iters = 6380 | loss: 0.894208 | acc: 0.71875
# Stats: epoch = 5 | iters = 6390 | loss: 0.672854 | acc: 0.875
# Stats: epoch = 5 | iters = 6400 | loss: 0.724449 | acc: 0.8125
# Stats: epoch = 5 | iters = 6410 | loss: 0.957879 | acc: 0.59375
# Stats: epoch = 5 | iters = 6420 | loss: 0.955449 | acc: 0.6875
# Stats: epoch = 5 | iters = 6430 | loss: 0.935438 | acc: 0.78125
# Stats: epoch = 5 | iters = 6440 | loss: 0.577092 | acc: 0.8125
# Stats: epoch = 5 | iters = 6450 | loss: 0.988921 | acc: 0.625
# Stats: epoch = 5 | iters = 6460 | loss: 1.09312 | acc: 0.65625
# Stats: epoch = 5 | iters = 6470 | loss: 0.821174 | acc: 0.71875
# Stats: epoch = 5 | iters = 6480 | loss: 0.966308 | acc: 0.71875
# Stats: epoch = 5 | iters = 6490 | loss: 1.22992 | acc: 0.5625
# Stats: epoch = 5 | iters = 6500 | loss: 0.73857 | acc: 0.8125
# Stats: epoch = 5 | iters = 6510 | loss: 0.820503 | acc: 0.75
# Stats: epoch = 5 | iters = 6520 | loss: 0.622586 | acc: 0.875
# Stats: epoch = 5 | iters = 6530 | loss: 0.793137 | acc: 0.75
# Stats: epoch = 5 | iters = 6540 | loss: 0.945004 | acc: 0.75
# Stats: epoch = 5 | iters = 6550 | loss: 0.933495 | acc: 0.8125
# Stats: epoch = 5 | iters = 6560 | loss: 0.758139 | acc: 0.78125
# Stats: epoch = 5 | iters = 6570 | loss: 0.632677 | acc: 0.84375
# Stats: epoch = 5 | iters = 6580 | loss: 1.04566 | acc: 0.75
# Stats: epoch = 5 | iters = 6590 | loss: 0.763022 | acc: 0.875
# Stats: epoch = 5 | iters = 6600 | loss: 0.888698 | acc: 0.65625
# Stats: epoch = 5 | iters = 6610 | loss: 0.724137 | acc: 0.8125
# Stats: epoch = 5 | iters = 6620 | loss: 0.551347 | acc: 0.84375
# Stats: epoch = 5 | iters = 6630 | loss: 0.694005 | acc: 0.78125
# Stats: epoch = 5 | iters = 6640 | loss: 1.09526 | acc: 0.65625
# Stats: epoch = 5 | iters = 6650 | loss: 1.02793 | acc: 0.6875
# Stats: epoch = 5 | iters = 6660 | loss: 1.03248 | acc: 0.6875
# Stats: epoch = 5 | iters = 6670 | loss: 0.907675 | acc: 0.78125
# Stats: epoch = 5 | iters = 6680 | loss: 1.00489 | acc: 0.71875
# Stats: epoch = 5 | iters = 6690 | loss: 0.642811 | acc: 0.84375
# Stats: epoch = 5 | iters = 6700 | loss: 0.854896 | acc: 0.6875
# Stats: epoch = 5 | iters = 6710 | loss: 0.798795 | acc: 0.78125
# Stats: epoch = 5 | iters = 6720 | loss: 0.980369 | acc: 0.65625
# Stats: epoch = 5 | iters = 6730 | loss: 0.776716 | acc: 0.75
# Stats: epoch = 5 | iters = 6740 | loss: 0.57404 | acc: 0.8125
# Stats: epoch = 5 | iters = 6750 | loss: 0.991164 | acc: 0.75
# Stats: epoch = 5 | iters = 6760 | loss: 0.843564 | acc: 0.65625
# Stats: epoch = 5 | iters = 6770 | loss: 0.682163 | acc: 0.875
# Stats: epoch = 5 | iters = 6780 | loss: 0.64182 | acc: 0.875
# Stats: epoch = 5 | iters = 6790 | loss: 0.87388 | acc: 0.75
# Stats: epoch = 5 | iters = 6800 | loss: 1.02047 | acc: 0.71875
# Stats: epoch = 5 | iters = 6810 | loss: 0.843755 | acc: 0.75
# Stats: epoch = 5 | iters = 6820 | loss: 0.775193 | acc: 0.84375
# Stats: epoch = 5 | iters = 6830 | loss: 0.617225 | acc: 0.8125
# Stats: epoch = 5 | iters = 6840 | loss: 0.883356 | acc: 0.6875
# Stats: epoch = 5 | iters = 6850 | loss: 0.806258 | acc: 0.75
# Stats: epoch = 5 | iters = 6860 | loss: 0.870505 | acc: 0.71875
# Stats: epoch = 5 | iters = 6870 | loss: 0.516903 | acc: 0.84375
# Stats: epoch = 5 | iters = 6880 | loss: 0.849759 | acc: 0.71875
# Stats: epoch = 5 | iters = 6890 | loss: 0.810163 | acc: 0.8125
# Stats: epoch = 5 | iters = 6900 | loss: 0.78439 | acc: 0.75
# Stats: epoch = 5 | iters = 6910 | loss: 0.888218 | acc: 0.6875
# Stats: epoch = 5 | iters = 6920 | loss: 0.717985 | acc: 0.8125
# Stats: epoch = 5 | iters = 6930 | loss: 0.841627 | acc: 0.78125
# Stats: epoch = 5 | iters = 6940 | loss: 0.651078 | acc: 0.8125
# Stats: epoch = 5 | iters = 6950 | loss: 0.91846 | acc: 0.71875
# Stats: epoch = 5 | iters = 6960 | loss: 1.26404 | acc: 0.59375
# Stats: epoch = 5 | iters = 6970 | loss: 0.89888 | acc: 0.6875
# Stats: epoch = 5 | iters = 6980 | loss: 0.73255 | acc: 0.78125
# Stats: epoch = 5 | iters = 6990 | loss: 0.734207 | acc: 0.6875
# Stats: epoch = 5 | iters = 7000 | loss: 1.15501 | acc: 0.75
# Stats: epoch = 5 | iters = 7010 | loss: 1.01794 | acc: 0.71875
# Stats: epoch = 5 | iters = 7020 | loss: 1.01656 | acc: 0.65625
# Stats: epoch = 5 | iters = 7030 | loss: 0.723233 | acc: 0.78125
# Stats: epoch = 5 | iters = 7040 | loss: 0.981922 | acc: 0.6875
# Stats: epoch = 5 | iters = 7050 | loss: 0.761326 | acc: 0.75
# Stats: epoch = 5 | iters = 7060 | loss: 1.00754 | acc: 0.6875
# Stats: epoch = 6 | iters = 7070 | loss: 1.10685 | acc: 0.59375
# Stats: epoch = 6 | iters = 7080 | loss: 0.718019 | acc: 0.78125
# Stats: epoch = 6 | iters = 7090 | loss: 0.659975 | acc: 0.8125
# Stats: epoch = 6 | iters = 7100 | loss: 1.03175 | acc: 0.625
# Stats: epoch = 6 | iters = 7110 | loss: 0.675168 | acc: 0.75
# Stats: epoch = 6 | iters = 7120 | loss: 0.57566 | acc: 0.8125
# Stats: epoch = 6 | iters = 7130 | loss: 0.889312 | acc: 0.6875
# Stats: epoch = 6 | iters = 7140 | loss: 0.81039 | acc: 0.78125
# Stats: epoch = 6 | iters = 7150 | loss: 0.714772 | acc: 0.78125
# Stats: epoch = 6 | iters = 7160 | loss: 1.05192 | acc: 0.65625
# Stats: epoch = 6 | iters = 7170 | loss: 1.13078 | acc: 0.65625
# Stats: epoch = 6 | iters = 7180 | loss: 1.047 | acc: 0.65625
# Stats: epoch = 6 | iters = 7190 | loss: 0.842418 | acc: 0.78125
# Stats: epoch = 6 | iters = 7200 | loss: 0.804391 | acc: 0.75
# Stats: epoch = 6 | iters = 7210 | loss: 0.998436 | acc: 0.625
# Stats: epoch = 6 | iters = 7220 | loss: 0.733637 | acc: 0.8125
# Stats: epoch = 6 | iters = 7230 | loss: 0.85532 | acc: 0.84375
# Stats: epoch = 6 | iters = 7240 | loss: 0.467018 | acc: 0.84375
# Stats: epoch = 6 | iters = 7250 | loss: 0.714305 | acc: 0.75
# Stats: epoch = 6 | iters = 7260 | loss: 1.00998 | acc: 0.65625
# Stats: epoch = 6 | iters = 7270 | loss: 0.719993 | acc: 0.8125
# Stats: epoch = 6 | iters = 7280 | loss: 0.662742 | acc: 0.84375
# Stats: epoch = 6 | iters = 7290 | loss: 1.2121 | acc: 0.65625
# Stats: epoch = 6 | iters = 7300 | loss: 0.8748 | acc: 0.65625
# Stats: epoch = 6 | iters = 7310 | loss: 0.50863 | acc: 0.84375
# Stats: epoch = 6 | iters = 7320 | loss: 0.939165 | acc: 0.71875
# Stats: epoch = 6 | iters = 7330 | loss: 0.803283 | acc: 0.78125
# Stats: epoch = 6 | iters = 7340 | loss: 0.581871 | acc: 0.84375
# Stats: epoch = 6 | iters = 7350 | loss: 0.572742 | acc: 0.84375
# Stats: epoch = 6 | iters = 7360 | loss: 0.592093 | acc: 0.8125
# Stats: epoch = 6 | iters = 7370 | loss: 0.558808 | acc: 0.90625
# Stats: epoch = 6 | iters = 7380 | loss: 0.73008 | acc: 0.78125
# Stats: epoch = 6 | iters = 7390 | loss: 0.801438 | acc: 0.6875
# Stats: epoch = 6 | iters = 7400 | loss: 0.820904 | acc: 0.78125
# Stats: epoch = 6 | iters = 7410 | loss: 0.765722 | acc: 0.6875
# Stats: epoch = 6 | iters = 7420 | loss: 0.763992 | acc: 0.75
# Stats: epoch = 6 | iters = 7430 | loss: 0.853139 | acc: 0.75
# Stats: epoch = 6 | iters = 7440 | loss: 0.767107 | acc: 0.78125
# Stats: epoch = 6 | iters = 7450 | loss: 0.597762 | acc: 0.875
# Stats: epoch = 6 | iters = 7460 | loss: 0.644397 | acc: 0.84375
# Stats: epoch = 6 | iters = 7470 | loss: 0.610953 | acc: 0.875
# Stats: epoch = 6 | iters = 7480 | loss: 0.692827 | acc: 0.75
# Stats: epoch = 6 | iters = 7490 | loss: 0.926508 | acc: 0.75
# Stats: epoch = 6 | iters = 7500 | loss: 0.659561 | acc: 0.84375
# Stats: epoch = 6 | iters = 7510 | loss: 0.748796 | acc: 0.84375
# Stats: epoch = 6 | iters = 7520 | loss: 0.584603 | acc: 0.90625
# Stats: epoch = 6 | iters = 7530 | loss: 0.80015 | acc: 0.6875
# Stats: epoch = 6 | iters = 7540 | loss: 0.886217 | acc: 0.65625
# Stats: epoch = 6 | iters = 7550 | loss: 0.705743 | acc: 0.8125
# Stats: epoch = 6 | iters = 7560 | loss: 1.01986 | acc: 0.65625
# Stats: epoch = 6 | iters = 7570 | loss: 0.763987 | acc: 0.71875
# Stats: epoch = 6 | iters = 7580 | loss: 0.675811 | acc: 0.84375
# Stats: epoch = 6 | iters = 7590 | loss: 0.912627 | acc: 0.71875
# Stats: epoch = 6 | iters = 7600 | loss: 0.649171 | acc: 0.75
# Stats: epoch = 6 | iters = 7610 | loss: 0.499547 | acc: 0.8125
# Stats: epoch = 6 | iters = 7620 | loss: 0.80894 | acc: 0.78125
# Stats: epoch = 6 | iters = 7630 | loss: 0.710372 | acc: 0.78125
# Stats: epoch = 6 | iters = 7640 | loss: 0.701377 | acc: 0.8125
# Stats: epoch = 6 | iters = 7650 | loss: 0.695848 | acc: 0.8125
# Stats: epoch = 6 | iters = 7660 | loss: 0.831561 | acc: 0.84375
# Stats: epoch = 6 | iters = 7670 | loss: 0.800515 | acc: 0.84375
# Stats: epoch = 6 | iters = 7680 | loss: 0.848187 | acc: 0.78125
# Stats: epoch = 6 | iters = 7690 | loss: 0.646468 | acc: 0.8125
# Stats: epoch = 6 | iters = 7700 | loss: 0.718195 | acc: 0.84375
# Stats: epoch = 6 | iters = 7710 | loss: 0.621399 | acc: 0.84375
# ...
# Stats: epoch = 17 | iters = 21110 | loss: 0.389489 | acc: 0.90625
# Stats: epoch = 17 | iters = 21120 | loss: 0.372701 | acc: 0.84375
# Stats: epoch = 17 | iters = 21130 | loss: 0.344003 | acc: 0.9375
# Stats: epoch = 17 | iters = 21140 | loss: 0.312454 | acc: 0.96875
# Stats: epoch = 17 | iters = 21150 | loss: 0.390914 | acc: 0.90625
# Stats: epoch = 17 | iters = 21160 | loss: 0.336019 | acc: 0.96875
# Stats: epoch = 17 | iters = 21170 | loss: 0.48501 | acc: 0.875
# Stats: epoch = 17 | iters = 21180 | loss: 0.474583 | acc: 0.90625
# Stats: epoch = 18 | iters = 21190 | loss: 0.379776 | acc: 0.90625
# Stats: epoch = 18 | iters = 21200 | loss: 0.320165 | acc: 0.96875
# Stats: epoch = 18 | iters = 21210 | loss: 0.359102 | acc: 0.9375
# Stats: epoch = 18 | iters = 21220 | loss: 0.286917 | acc: 0.9375
# Stats: epoch = 18 | iters = 21230 | loss: 0.506514 | acc: 0.8125
# Stats: epoch = 18 | iters = 21240 | loss: 0.286199 | acc: 0.96875
# Stats: epoch = 18 | iters = 21250 | loss: 0.504823 | acc: 0.90625
# Stats: epoch = 18 | iters = 21260 | loss: 0.345367 | acc: 0.90625
# Stats: epoch = 18 | iters = 21270 | loss: 0.355985 | acc: 0.90625
# Stats: epoch = 18 | iters = 21280 | loss: 0.372473 | acc: 0.9375
# Stats: epoch = 18 | iters = 21290 | loss: 0.318413 | acc: 0.90625
# Stats: epoch = 18 | iters = 21300 | loss: 0.353735 | acc: 0.90625
# Stats: epoch = 18 | iters = 21310 | loss: 0.600424 | acc: 0.90625
# Stats: epoch = 18 | iters = 21320 | loss: 0.490586 | acc: 0.90625
# Stats: epoch = 18 | iters = 21330 | loss: 0.351204 | acc: 0.9375
# Stats: epoch = 18 | iters = 21340 | loss: 0.211002 | acc: 1.0
# Stats: epoch = 18 | iters = 21350 | loss: 0.326896 | acc: 0.9375
# Stats: epoch = 18 | iters = 21360 | loss: 0.23559 | acc: 1.0
# Stats: epoch = 18 | iters = 21370 | loss: 0.371814 | acc: 0.90625
# Stats: epoch = 18 | iters = 21380 | loss: 0.432337 | acc: 0.9375
# Stats: epoch = 18 | iters = 21390 | loss: 0.47724 | acc: 0.84375
# Stats: epoch = 18 | iters = 21400 | loss: 0.424675 | acc: 0.9375
# Stats: epoch = 18 | iters = 21410 | loss: 0.354584 | acc: 0.9375
# Stats: epoch = 18 | iters = 21420 | loss: 0.300853 | acc: 0.9375
# Stats: epoch = 18 | iters = 21430 | loss: 0.193286 | acc: 1.0
# Stats: epoch = 18 | iters = 21440 | loss: 0.320532 | acc: 0.9375
# Stats: epoch = 18 | iters = 21450 | loss: 0.198415 | acc: 1.0
# Stats: epoch = 18 | iters = 21460 | loss: 0.294651 | acc: 0.96875
# Stats: epoch = 18 | iters = 21470 | loss: 0.467789 | acc: 0.9375
# Stats: epoch = 18 | iters = 21480 | loss: 0.537766 | acc: 0.84375
# Stats: epoch = 18 | iters = 21490 | loss: 0.532985 | acc: 0.9375
# Stats: epoch = 18 | iters = 21500 | loss: 0.508726 | acc: 0.875
# Stats: epoch = 18 | iters = 21510 | loss: 0.486893 | acc: 0.875
# Stats: epoch = 18 | iters = 21520 | loss: 0.340883 | acc: 0.90625
# Stats: epoch = 18 | iters = 21530 | loss: 0.290727 | acc: 0.9375
# Stats: epoch = 18 | iters = 21540 | loss: 0.415441 | acc: 0.90625
# Stats: epoch = 18 | iters = 21550 | loss: 0.303885 | acc: 0.9375
# Stats: epoch = 18 | iters = 21560 | loss: 0.465897 | acc: 0.84375
# Stats: epoch = 18 | iters = 21570 | loss: 0.239155 | acc: 0.96875
# Stats: epoch = 18 | iters = 21580 | loss: 0.289434 | acc: 1.0
# Stats: epoch = 18 | iters = 21590 | loss: 0.260014 | acc: 0.96875
# Stats: epoch = 18 | iters = 21600 | loss: 0.450183 | acc: 0.90625
# Stats: epoch = 18 | iters = 21610 | loss: 0.278006 | acc: 0.96875
# Stats: epoch = 18 | iters = 21620 | loss: 0.448613 | acc: 0.90625
# Stats: epoch = 18 | iters = 21630 | loss: 0.487653 | acc: 0.90625
# Stats: epoch = 18 | iters = 21640 | loss: 0.489427 | acc: 0.875
# Stats: epoch = 18 | iters = 21650 | loss: 0.212964 | acc: 0.96875
# Stats: epoch = 18 | iters = 21660 | loss: 0.480882 | acc: 0.875
# Stats: epoch = 18 | iters = 21670 | loss: 0.437367 | acc: 0.90625
# Stats: epoch = 18 | iters = 21680 | loss: 0.515091 | acc: 0.90625
# Stats: epoch = 18 | iters = 21690 | loss: 0.403827 | acc: 0.90625
# Stats: epoch = 18 | iters = 21700 | loss: 0.466679 | acc: 0.9375
# Stats: epoch = 18 | iters = 21710 | loss: 0.5036 | acc: 0.90625
# Stats: epoch = 18 | iters = 21720 | loss: 0.417428 | acc: 0.875
# Stats: epoch = 18 | iters = 21730 | loss: 0.449533 | acc: 0.875
# Stats: epoch = 18 | iters = 21740 | loss: 0.552995 | acc: 0.84375
# Stats: epoch = 18 | iters = 21750 | loss: 0.397754 | acc: 0.90625
# Stats: epoch = 18 | iters = 21760 | loss: 0.274066 | acc: 1.0
# Stats: epoch = 18 | iters = 21770 | loss: 0.254678 | acc: 0.96875
# Stats: epoch = 18 | iters = 21780 | loss: 0.237613 | acc: 0.96875
# Stats: epoch = 18 | iters = 21790 | loss: 0.32186 | acc: 0.9375
# Stats: epoch = 18 | iters = 21800 | loss: 0.510275 | acc: 0.875
# Stats: epoch = 18 | iters = 21810 | loss: 0.499457 | acc: 0.84375
# Stats: epoch = 18 | iters = 21820 | loss: 0.301327 | acc: 0.9375
# Stats: epoch = 18 | iters = 21830 | loss: 0.364637 | acc: 0.96875
# Stats: epoch = 18 | iters = 21840 | loss: 0.397348 | acc: 0.90625
# Stats: epoch = 18 | iters = 21850 | loss: 0.404819 | acc: 0.90625
# Stats: epoch = 18 | iters = 21860 | loss: 0.357172 | acc: 0.96875
# Stats: epoch = 18 | iters = 21870 | loss: 0.279656 | acc: 0.96875
# Stats: epoch = 18 | iters = 21880 | loss: 0.503493 | acc: 0.875
# Stats: epoch = 18 | iters = 21890 | loss: 0.170978 | acc: 1.0
# Stats: epoch = 18 | iters = 21900 | loss: 0.193818 | acc: 0.96875
# Stats: epoch = 18 | iters = 21910 | loss: 0.258157 | acc: 0.96875
# Stats: epoch = 18 | iters = 21920 | loss: 0.351016 | acc: 0.9375
# Stats: epoch = 18 | iters = 21930 | loss: 0.278467 | acc: 0.90625
# Stats: epoch = 18 | iters = 21940 | loss: 0.365713 | acc: 0.9375
# Stats: epoch = 18 | iters = 21950 | loss: 0.416793 | acc: 0.90625
# Stats: epoch = 18 | iters = 21960 | loss: 0.536549 | acc: 0.875
# Stats: epoch = 18 | iters = 21970 | loss: 0.45785 | acc: 0.8125
# Stats: epoch = 18 | iters = 21980 | loss: 0.260469 | acc: 0.96875
# Stats: epoch = 18 | iters = 21990 | loss: 0.246786 | acc: 0.9375
# Stats: epoch = 18 | iters = 22000 | loss: 0.557446 | acc: 0.875
# Stats: epoch = 18 | iters = 22010 | loss: 0.401253 | acc: 0.9375
# Stats: epoch = 18 | iters = 22020 | loss: 0.37197 | acc: 0.9375
# Stats: epoch = 18 | iters = 22030 | loss: 0.309111 | acc: 0.96875
# Stats: epoch = 18 | iters = 22040 | loss: 0.338762 | acc: 0.90625
# Stats: epoch = 18 | iters = 22050 | loss: 0.35159 | acc: 0.9375
# Stats: epoch = 18 | iters = 22060 | loss: 0.479303 | acc: 0.90625
# Stats: epoch = 18 | iters = 22070 | loss: 0.249158 | acc: 0.96875
# Stats: epoch = 18 | iters = 22080 | loss: 0.204025 | acc: 1.0
# Stats: epoch = 18 | iters = 22090 | loss: 0.368437 | acc: 0.9375
# Stats: epoch = 18 | iters = 22100 | loss: 0.286933 | acc: 1.0
# Stats: epoch = 18 | iters = 22110 | loss: 0.476994 | acc: 0.84375
# Stats: epoch = 18 | iters = 22120 | loss: 0.468446 | acc: 0.84375
# Stats: epoch = 18 | iters = 22130 | loss: 0.248047 | acc: 0.9375
# Stats: epoch = 18 | iters = 22140 | loss: 0.326589 | acc: 0.90625
# Stats: epoch = 18 | iters = 22150 | loss: 0.187451 | acc: 1.0
# Stats: epoch = 18 | iters = 22160 | loss: 0.500064 | acc: 0.84375
# Stats: epoch = 18 | iters = 22170 | loss: 0.405365 | acc: 0.9375
# Stats: epoch = 18 | iters = 22180 | loss: 0.379748 | acc: 0.875
# Stats: epoch = 18 | iters = 22190 | loss: 0.325288 | acc: 0.90625
# Stats: epoch = 18 | iters = 22200 | loss: 0.390995 | acc: 0.9375
# Stats: epoch = 18 | iters = 22210 | loss: 0.277606 | acc: 0.96875
# Stats: epoch = 18 | iters = 22220 | loss: 0.334349 | acc: 0.9375
# Stats: epoch = 18 | iters = 22230 | loss: 0.423329 | acc: 0.875
# Stats: epoch = 18 | iters = 22240 | loss: 0.168973 | acc: 1.0
# Stats: epoch = 18 | iters = 22250 | loss: 0.239661 | acc: 0.96875
# Stats: epoch = 18 | iters = 22260 | loss: 0.525277 | acc: 0.875
# Stats: epoch = 18 | iters = 22270 | loss: 0.363799 | acc: 0.90625
# Stats: epoch = 18 | iters = 22280 | loss: 0.281069 | acc: 0.90625
# Stats: epoch = 18 | iters = 22290 | loss: 0.499035 | acc: 0.8125
# Stats: epoch = 18 | iters = 22300 | loss: 0.555998 | acc: 0.875
# Stats: epoch = 18 | iters = 22310 | loss: 0.278607 | acc: 0.96875
# Stats: epoch = 18 | iters = 22320 | loss: 0.510001 | acc: 0.90625
# Stats: epoch = 18 | iters = 22330 | loss: 0.342239 | acc: 0.9375
# Stats: epoch = 18 | iters = 22340 | loss: 0.287744 | acc: 0.96875
# Stats: epoch = 18 | iters = 22350 | loss: 0.247966 | acc: 0.9375
# Stats: epoch = 18 | iters = 22360 | loss: 0.255231 | acc: 0.9375
# Stats: epoch = 19 | iters = 22370 | loss: 0.374494 | acc: 0.9375
# Stats: epoch = 19 | iters = 22380 | loss: 0.329948 | acc: 0.90625
# Stats: epoch = 19 | iters = 22390 | loss: 0.194038 | acc: 0.9375
# Stats: epoch = 19 | iters = 22400 | loss: 0.412826 | acc: 0.875
# Stats: epoch = 19 | iters = 22410 | loss: 0.258647 | acc: 0.96875
# Stats: epoch = 19 | iters = 22420 | loss: 0.299191 | acc: 0.96875
# Stats: epoch = 19 | iters = 22430 | loss: 0.234775 | acc: 0.96875
# Stats: epoch = 19 | iters = 22440 | loss: 0.39048 | acc: 0.96875
# Stats: epoch = 19 | iters = 22450 | loss: 0.343835 | acc: 0.9375
# Stats: epoch = 19 | iters = 22460 | loss: 0.189876 | acc: 1.0
# Stats: epoch = 19 | iters = 22470 | loss: 0.317412 | acc: 0.96875
# Stats: epoch = 19 | iters = 22480 | loss: 0.24505 | acc: 0.96875
# Stats: epoch = 19 | iters = 22490 | loss: 0.185982 | acc: 1.0
# Stats: epoch = 19 | iters = 22500 | loss: 0.428224 | acc: 0.875
# Stats: epoch = 19 | iters = 22510 | loss: 0.316455 | acc: 0.9375
# Stats: epoch = 19 | iters = 22520 | loss: 0.381298 | acc: 0.9375
# Stats: epoch = 19 | iters = 22530 | loss: 0.423254 | acc: 0.9375
# Stats: epoch = 19 | iters = 22540 | loss: 0.290753 | acc: 0.96875
# Stats: epoch = 19 | iters = 22550 | loss: 0.641506 | acc: 0.84375
# Stats: epoch = 19 | iters = 22560 | loss: 0.368282 | acc: 0.90625
# Stats: epoch = 19 | iters = 22570 | loss: 0.604252 | acc: 0.78125
# Stats: epoch = 19 | iters = 22580 | loss: 0.310273 | acc: 0.9375
# Stats: epoch = 19 | iters = 22590 | loss: 0.312685 | acc: 0.9375
# Stats: epoch = 19 | iters = 22600 | loss: 0.259882 | acc: 0.96875
# Stats: epoch = 19 | iters = 22610 | loss: 0.410976 | acc: 0.90625
# Stats: epoch = 19 | iters = 22620 | loss: 0.352742 | acc: 0.875
# Stats: epoch = 19 | iters = 22630 | loss: 0.313746 | acc: 0.9375
# Stats: epoch = 19 | iters = 22640 | loss: 0.25254 | acc: 0.96875
# Stats: epoch = 19 | iters = 22650 | loss: 0.389969 | acc: 0.96875
# Stats: epoch = 19 | iters = 22660 | loss: 0.319177 | acc: 0.9375
# Stats: epoch = 19 | iters = 22670 | loss: 0.47351 | acc: 0.875
# Stats: epoch = 19 | iters = 22680 | loss: 0.377779 | acc: 0.90625
# Stats: epoch = 19 | iters = 22690 | loss: 0.333084 | acc: 0.9375
# Stats: epoch = 19 | iters = 22700 | loss: 0.241513 | acc: 0.96875
# Stats: epoch = 19 | iters = 22710 | loss: 0.381502 | acc: 0.90625
# Stats: epoch = 19 | iters = 22720 | loss: 0.330905 | acc: 0.96875
# Stats: epoch = 19 | iters = 22730 | loss: 0.477253 | acc: 0.84375
# Stats: epoch = 19 | iters = 22740 | loss: 0.559073 | acc: 0.875
# Stats: epoch = 19 | iters = 22750 | loss: 0.388927 | acc: 0.875
# Stats: epoch = 19 | iters = 22760 | loss: 0.315538 | acc: 0.90625
# Stats: epoch = 19 | iters = 22770 | loss: 0.43472 | acc: 0.875
# Stats: epoch = 19 | iters = 22780 | loss: 0.300348 | acc: 0.9375
# Stats: epoch = 19 | iters = 22790 | loss: 0.278383 | acc: 1.0
# Stats: epoch = 19 | iters = 22800 | loss: 0.448053 | acc: 0.90625
# Stats: epoch = 19 | iters = 22810 | loss: 0.226943 | acc: 0.96875
# Stats: epoch = 19 | iters = 22820 | loss: 0.270059 | acc: 0.96875
# Stats: epoch = 19 | iters = 22830 | loss: 0.343221 | acc: 0.9375
# Stats: epoch = 19 | iters = 22840 | loss: 0.268907 | acc: 0.9375
# Stats: epoch = 19 | iters = 22850 | loss: 0.26402 | acc: 0.96875
# Stats: epoch = 19 | iters = 22860 | loss: 0.173429 | acc: 1.0
# Stats: epoch = 19 | iters = 22870 | loss: 0.34934 | acc: 0.9375
# Stats: epoch = 19 | iters = 22880 | loss: 0.267288 | acc: 0.9375
# Stats: epoch = 19 | iters = 22890 | loss: 0.325198 | acc: 0.9375
# Stats: epoch = 19 | iters = 22900 | loss: 0.533559 | acc: 0.875
# Stats: epoch = 19 | iters = 22910 | loss: 0.252317 | acc: 0.96875
# Stats: epoch = 19 | iters = 22920 | loss: 0.448459 | acc: 0.90625
# Stats: epoch = 19 | iters = 22930 | loss: 0.462473 | acc: 0.90625
# Stats: epoch = 19 | iters = 22940 | loss: 0.250952 | acc: 0.96875
# Stats: epoch = 19 | iters = 22950 | loss: 0.542469 | acc: 0.875
# Stats: epoch = 19 | iters = 22960 | loss: 0.270983 | acc: 0.96875
# Stats: epoch = 19 | iters = 22970 | loss: 0.243654 | acc: 0.90625
# Stats: epoch = 19 | iters = 22980 | loss: 0.269116 | acc: 0.9375
# Stats: epoch = 19 | iters = 22990 | loss: 0.3683 | acc: 0.90625
# Stats: epoch = 19 | iters = 23000 | loss: 0.230973 | acc: 0.96875
# Stats: epoch = 19 | iters = 23010 | loss: 0.281302 | acc: 0.96875
# Stats: epoch = 19 | iters = 23020 | loss: 0.497969 | acc: 0.90625
# Stats: epoch = 19 | iters = 23030 | loss: 0.307996 | acc: 0.9375
# Stats: epoch = 19 | iters = 23040 | loss: 0.380219 | acc: 0.96875
# Stats: epoch = 19 | iters = 23050 | loss: 0.361874 | acc: 0.90625
# Stats: epoch = 19 | iters = 23060 | loss: 0.378564 | acc: 0.90625
# Stats: epoch = 19 | iters = 23070 | loss: 0.306796 | acc: 0.96875
# Stats: epoch = 19 | iters = 23080 | loss: 0.2748 | acc: 0.9375
# Stats: epoch = 19 | iters = 23090 | loss: 0.343834 | acc: 0.9375
# Stats: epoch = 19 | iters = 23100 | loss: 0.610295 | acc: 0.875
# Stats: epoch = 19 | iters = 23110 | loss: 0.290271 | acc: 0.9375
# Stats: epoch = 19 | iters = 23120 | loss: 0.30213 | acc: 0.96875
# Stats: epoch = 19 | iters = 23130 | loss: 0.326284 | acc: 0.9375
# Stats: epoch = 19 | iters = 23140 | loss: 0.497099 | acc: 0.84375
# Stats: epoch = 19 | iters = 23150 | loss: 0.21991 | acc: 0.96875
# Stats: epoch = 19 | iters = 23160 | loss: 0.248351 | acc: 0.96875
# Stats: epoch = 19 | iters = 23170 | loss: 0.407144 | acc: 0.90625
# Stats: epoch = 19 | iters = 23180 | loss: 0.193158 | acc: 1.0
# Stats: epoch = 19 | iters = 23190 | loss: 0.352199 | acc: 0.90625
# Stats: epoch = 19 | iters = 23200 | loss: 0.280947 | acc: 0.96875
# Stats: epoch = 19 | iters = 23210 | loss: 0.466666 | acc: 0.875
# Stats: epoch = 19 | iters = 23220 | loss: 0.298532 | acc: 0.96875
# Stats: epoch = 19 | iters = 23230 | loss: 0.251303 | acc: 1.0
# Stats: epoch = 19 | iters = 23240 | loss: 0.203598 | acc: 0.96875
# Stats: epoch = 19 | iters = 23250 | loss: 0.446829 | acc: 0.875
# Stats: epoch = 19 | iters = 23260 | loss: 0.508759 | acc: 0.84375
# Stats: epoch = 19 | iters = 23270 | loss: 0.441462 | acc: 0.84375
# Stats: epoch = 19 | iters = 23280 | loss: 0.309883 | acc: 0.90625
# Stats: epoch = 19 | iters = 23290 | loss: 0.297198 | acc: 0.9375
# Stats: epoch = 19 | iters = 23300 | loss: 0.479072 | acc: 0.84375
# Stats: epoch = 19 | iters = 23310 | loss: 0.209042 | acc: 1.0
# Stats: epoch = 19 | iters = 23320 | loss: 0.222591 | acc: 0.9375
# Stats: epoch = 19 | iters = 23330 | loss: 0.238145 | acc: 0.9375
# Stats: epoch = 19 | iters = 23340 | loss: 0.547139 | acc: 0.875
# Stats: epoch = 19 | iters = 23350 | loss: 0.522846 | acc: 0.875
# Stats: epoch = 19 | iters = 23360 | loss: 0.436186 | acc: 0.9375
# Stats: epoch = 19 | iters = 23370 | loss: 0.308338 | acc: 0.875
# Stats: epoch = 19 | iters = 23380 | loss: 0.329545 | acc: 0.9375
# Stats: epoch = 19 | iters = 23390 | loss: 0.524374 | acc: 0.84375
# Stats: epoch = 19 | iters = 23400 | loss: 0.215147 | acc: 0.96875
# Stats: epoch = 19 | iters = 23410 | loss: 0.26891 | acc: 0.9375
# Stats: epoch = 19 | iters = 23420 | loss: 0.226118 | acc: 1.0
# Stats: epoch = 19 | iters = 23430 | loss: 0.161274 | acc: 1.0
# Stats: epoch = 19 | iters = 23440 | loss: 0.315818 | acc: 0.96875
# Stats: epoch = 19 | iters = 23450 | loss: 0.441805 | acc: 0.84375
# Stats: epoch = 19 | iters = 23460 | loss: 0.314937 | acc: 0.9375
# Stats: epoch = 19 | iters = 23470 | loss: 0.412085 | acc: 0.90625
# Stats: epoch = 19 | iters = 23480 | loss: 0.286514 | acc: 0.90625
# Stats: epoch = 19 | iters = 23490 | loss: 0.199372 | acc: 1.0
# Stats: epoch = 19 | iters = 23500 | loss: 0.407097 | acc: 0.875
# Stats: epoch = 19 | iters = 23510 | loss: 0.370486 | acc: 0.90625
# Stats: epoch = 19 | iters = 23520 | loss: 0.45499 | acc: 0.90625
# Stats: epoch = 19 | iters = 23530 | loss: 0.220455 | acc: 1.0
# Stats: epoch = 19 | iters = 23540 | loss: 0.211578 | acc: 0.96875
#
# Test Stats:
#     loss = 0.338655 | acc: 0.930622
#     prec = 0.93062175617 | rec = 0.93062175617 | f1 = 0.93062175617

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def graph_loss_acc(train_losses, train_accs):
    fig, ax1 = plt.subplots(figsize=(10,8))
    ax2 = ax1.twinx()
    ln1 = ax1.plot(train_losses, color='r', label='loss')
    ln2 = ax2.plot(train_accs, color='g', label='acc')
    lns = ln1 + ln2
    labs = [l.get_label() for l in lns]
    ax1.set_xlabel('# iterations')
    ax1.set_ylabel('Loss')
    ax2.set_ylabel('Accuracy')
    ax2.legend(lns, labs, loc='upper left') # ax1.legend causes legend to be crossed by grid lines.
    plt.title('Loss & Accuracy')
    plt.show()

# %%
graph_loss_acc(train_losses, train_accs)

# %% [markdown]
# ### RESULTS SUMMARY

# %%
# CV ROUND #2

#               200   400   600   800   1000  1200  1400  1600  1800  2000
accs_lex     = [78.5, 79.1, 77.8, 77.5, 80.8, 81.8, 82.1, 85.4, 87.7, 88.1]
accs_lexdisc = [77.3, 76.5, 78.1, 78.4, 85.9, 86.1, 86.7, 90.9, 91.2, 91.7]

# %%
plt.plot(accs_lex, '-o',label='CNN2')
plt.plot(accs_lexdisc, '-*', label='CNN2-Disc')
plt.ylim((70,100))
plt.xticks(np.arange(10),[200,400,600,800,1000,1200,1400,1600,1800,2000])
plt.title('CNN Authorship Attribution')
plt.xlabel('Chunk Sizes')
plt.ylabel('F1')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### HEATMAP

# %%
print grads.shape, X_test.shape
# Out:
# (9441, 999, 50) (9441, 999)

# %%
def to_charticks(x):
    return [a+b for a,b in map(lambda idx:index2bichar[idx], x)]

def heatmap(idx, start, end, step=50, cmap_type='hot_r'):
    t = abs(grads[idx]).max(axis=1)
    indices = range(start, end+1, step)
    num_bars = len(indices)-1
    f, ax = plt.subplots(num_bars,figsize=(20,20)) # figsize=(width,height)
    f.tight_layout()
    for i in range(num_bars):
        ax[i].imshow(t[indices[i]:indices[i+1]][np.newaxis,:], cmap=cmap_type, interpolation='nearest')
        ax[i].set_xticks(np.arange(step))
        ax[i].set_xticklabels(to_charticks(X_test[idx])[indices[i]:indices[i+1]])

# %%
heatmap(1,0,1000)
